# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# # Практическое задание 6. Бустинговое
#
# ## Общая информация
#
# Дата выдачи: 12.12.2024
#
# Мягкий дедлайн: 22.12.2024 23:59 MSK
#
# Жёсткий дедлайн: 22.12.2024 23:59 MSK
#
# ## Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# ## Формат сдачи
# Задания сдаются через систему anytask. Посылка должна содержать:
# * Ноутбук homework-practice-06-Username.ipynb
#
# Username — ваша фамилия на латинице

# %% [markdown]
# ## О задании
#
# В этом задании вам предстоит вручную запрограммировать один из самых мощных алгоритмов машинного обучения — бустинг. Однако с большой силой приходит и большая ответственность, так что заодно научимся, как его правильно готовить

# %%
from warnings import filterwarnings

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.sparse import load_npz
from sklearn.model_selection import train_test_split

sns.set(style='darkgrid')
filterwarnings('ignore')

# %%
X = load_npz('x.npz')
y = np.load('y.npy')

# %% [markdown]
# Разделим на обучающую, валидационную и тестовую выборки (оставьте `random_state=1337` для воспроизводимости).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, random_state=1337)

X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((18825, 169), (2354, 169), (2353, 169))

# %% [markdown]
# ---
#
# ## Задание 1. Базовый градиентный бустинг (4 балла)
#
# Первая часть посвящена реализации собственного градиентного бустинга. Обращаем внимание, что пользоваться готовыми реализациями <font color='lightcoral'>**нельзя**</font>, если специально не оговорено. На все <font color='plum'>**вопросы**</font> должен быть <font color='plum'>**ответ**</font>. В заданиях есть референсы для параметров, которые нужно сделать, на случай, если объяснение из ноутбука непонятно, тогда советуем обратиться к соответствующей документации
#
# Вам нужно дописать код в файлике `boosting.py`. Для вас уже подготовлен шаблон класса `Boosting`, вы можете менять его по своему усмотрению.
#
# ### Инструкции для функций:
#
# #### `__init__`
#
# Обязательные параметры:
#  — `base_model_class` — класс базовой модели нашего бустинга
#  — `base_model_params` — словарь с гиперпараметрами для базовой модели
#  — `n_estimators` — какое количество базовых моделей нужно обучить
#  — `learning_rate` — темп обучения, должен быть из полуинтервала $(0, 1]$
#
# #### `fit`
#
# В `fit` приходит выборка, на которой мы обучаем новые базовые модели
#
# Сначала нам нужно сделать какую-то нулевую модель, сделать предсказания (в шаблоне это нулевая модель, соответственно предсказания это просто `np.zeros`). После этого нужно обучить `n_estimators` базовых моделей (как и на что обучаются базовые модели смотрите в лекциях и семинарах). После каждой обученной базовой модели мы должны обновить текущие предсказания, посчитать ошибку на выборке (используем `loss_fn` для этого) и найти новую оптимальную гамму
#
# После всего цикла обучения надо нарисовать график (если `plot=True`).
#
# #### `partial_fit`
#
# В `partial_fit` приходит обучающая выборка, на которую обучается новая базовая модель
#
# #### `predict_proba`
#
# В `predict_proba` приходит любая выборка, нужно предсказать вероятности для неё. Суммируем предсказания базовых моделей на этой выборке (не забываем про гаммы) и накидываем сигмоиду
#
# #### `plot_history`
#
# В `plot_history` приходит любая выборка, для которой последовательно считаются значения функции потерь и/или любой метрики, которую вы хотите посчитать, путем последовательного применения базовых моделей. Можно делать сразу во время обучения, можно делать иначе

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from boosting import Boosting

# %% [markdown]
# ### Проверка кода

# %%
boosting = Boosting(n_estimators=100)

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

assert len(boosting.models) == boosting.n_estimators
assert len(boosting.gammas) == boosting.n_estimators

assert boosting.predict_proba(X_test).shape == (X_test.shape[0], 2)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.8417
# Test ROC-AUC 0.8342

# %% [markdown]
# ---
#
# ## Задание 2. Имплементация гиперпараметров (2.5 балла + 3.5 бонус)
#
# Бустинг, как метод агрегации, предлагает несколько вариантов регуляризации безотносительно базовой модели. В этом пункте предлагается имплементировать часть из них. При необходимости можете обратиться к реализациям в вашей любимой библиотеке, там могут быть дополнительные пояснения и/или ссылки на оригинальные статьи
#
# <font color='lightcoral'>**Важно!**</font> После добавления каждого параметра проверьте, как это повлияет на качество. Специально крутить параметры не нужно, но важно увидеть, что перформанс модели изменился, в худшую или в лучшую сторону, для этого какие-то параметры нужны, пусть и от балды, <font color='lightcoral'>**дефолтные параметры не подойдут**</font>, они скорее для референса. Лучше всего это видно по графикам обучения <font color='lightcoral'>**на трейне и валидации**</font>, рекомендуется смотрить именно на них
#
# ### 2.1. Борьба с переобучением (0.5 балла)
#
# Как известно, бустинги бывают склонны к переобучению. Чтобы этого не допустить, можно контролировать процесс обучения и проверять критерий останова на валидации. Реализуйте такую процедуру, не забудьте, что всю предобработку, что вы будете делать для трейна, нужно будет повторить на валидации
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | <td colspan=3>`early_stopping_rounds`, `eval_set` |
#
# Добавьте параметры:
# - `early_stopping_rounds: int | None = 0` — число раундов для критерия останова. Если качество ухудшается на протяжении всех раундов подряд, останавливаем обучение
# - `X_val`, `y_val` или `eval_set: Tuple[np.ndarray] | None = None` — валидацонная выборка, на которой будем проверять переобучение

# %%
boosting = Boosting(n_estimators=100)

boosting.fit(X_train, y_train, X_valid, y_valid)
boosting.plot_history(X_valid, y_valid)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.8417
# Test ROC-AUC 0.8334

# %%
boosting = Boosting(n_estimators=100, early_stopping_rounds = 20)

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.8419
# Test ROC-AUC 0.8330

# %% [markdown]
# ### Бонус. Бустинг линейных моделей (0.5 балла)
#
# **<font color='plum'>Вопрос:** что произойдет при ансамблировании линейных моделей? Имеет ли это смысл?</font>
#
# <font color='plum'>**Ответ:** Не сразу понял, что будет, но в итоге пришел к тому, что произойдет чудо и да!! это имеет бооооольшоооой смысл!!!</font>
#
# Давайте убедимся. Обучите бустинг, где в качестве базовой модели будет линейная регрессия. Обязательно сохраните историю функции потерь и зафиксируйте время обучения. Можно взять уже готовый из <font color='lightblue'>**XGBoost**</font>, но будьте готовы разобраться с тем, как оттуда достать историю обучения
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `XGBClassifier(booster="gblinear")` | — | — |

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# Теперь возьмите `sklearn.linear_model.SGDClassifier` иобучите на тех же данных. Не забудьте вытащить историю функции потерь

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# Покажите на одном графике изменение функции потерь для бустинга и SGD классификатора. Сравните следующие параметры у бустинга и линейной модели:
#
# - время обучения
# - число итераций до сходимости
# - графики функции потерь на трейне и на валидации

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# <font color='plum'>**Вопрос:** Какой вывод вы можете сделать?</font>
#
# <font color='plum'>**Ответ:** вывод прост, каким бы человек не был, не стоит судить по внешности.</font>

# %% [markdown]
# ### 2.2. Бутстрап (0.5 балла)
# Как известно, при обучении базовых алгоритмов в беггинге, используется бутстрапированная выборка. Звучит хайпово, почему бы не попробовать сделать то же самое в бустинге?
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `subsample`, — | `subsample`, `bagging`| `subsample`, `bootstrap_type`|
#
# Вам нужно реализовать параметры:
# - `subsample: float | int = 1.0` — доля или число объектов, на которой будет обучаться базовая модель (какую часть составляет бутстрапная выборка от исходной обучающей). Соответствует бутстрапу типа `Bernoulli`. Каждый объект либо входит в подвыборку, либо нет
# - `bagging_temperature: float | int = 1.0` — веса объектов, которые попадают в выборку. Соответствует бутстрапу типа `Bayesian`. Каждый объект имеет определенный вес $t$, на который впоследствии домножается по формуле $w = (-\log(X))^t$, где $X \sim {U[0, 1]}$, после чего попадает в выборку. Таким образом можно сделать симуляцию повторений
# - `bootstrap_type: str | None = 'Bernoulli'` — тип бутстрапа
#
# <font color='plum'>**Вопрос:** как бутстрап может помочь в обучении с точки зрения смещения, разброса и вообще?</font>
#
# <font color='plum'>**Ответ:** как мы видим бутстрап это реально топчик, он делает свое дело и не задает лишних вопросов. Личено я хочу быть как бутстрап в будущем и стараюсь двигаться в этом направлении </font>

# %%
boosting = Boosting(n_estimators=100, subsample = 0.7)

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.9221
# Test ROC-AUC 0.9164

# %%
boosting = Boosting(n_estimators=100, bagging_temperature = 0.8)

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.8416
# Test ROC-AUC 0.8337

# %%
boosting = Boosting(n_estimators=100, bootstrap_type = "Bayesian")

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.9185
# Test ROC-AUC 0.9175

# %% [markdown]
# ### Бонус. GOSS (0.5 балла)
#
# Заметим, что во время обучения не все объекты одинаково важны. Один из вариантов это исправить — ввести какие-то веса на объекты, однако можно пойти чуть хитрее. В <font color='lightgreen'>**LightGBM**</font> придумали подход [Gradient-based One-side Sampling](https://www.microsoft.com/en-us/research/wp-content/uploads/2017/11/lightgbm.pdf)
#
# Давайте оценивать важность объектов в отдельный момент обучения нового дерева. Будем считать, какой антиградиент привносит каждый объект. Далее разобъем градиенты на 2 группы. Объекты с большими градиентами берутся все, с маленькими — только часть, по аналогии с бутстрапом, с отрицательными — выкидываются. И не забываем домножить на фактор, чтобы учесть выкинутые объекты. Подробнее в статье
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | — | `bagging='goss'`| `bootstrap_type='MVS'`|
#
# Параметры, которые нужно сделать:
#
# - `goss: bool | None = False` — GOSS бустинг или нет
# - `goss_k: float | int = 0.2` — доля объектов, градиенты которых будем считать большими. Все остальное — маленькими
# - `subsample: float | int = 0.3` — параметры сэмплинга для маленьких градиентов из пункта 2.1

# %%
boosting = Boosting(n_estimators=100, goss = True, goss_k = 0.1, goss_subsample = 0.2)

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9883
# Valid ROC-AUC 0.9255
# Test ROC-AUC 0.9228

# %% [markdown]
# ### 2.3. Работа с признаками (1 балл)
#
# 1. Помимо выбора случайных объектов, есть идея выбирать случайное подмножество признаков, заложенная в Random Forest. Мотивация это делать точно та же самая, что и в бутстрапировании, за это будет отвечать `rsm`
#
# 2. С другой стороны, вместо того, чтобы выкидывать признаки, можно попробовать проредить их множество значений, применив бинаризацию. В идеале это стоит делать с датасетом до обучения модели, но не обязательно, можно, например, на этапе `fit`, а в `partial_fit` приходит уже квантизованный датасет. Для этого существует множество алгоритмов, мы предлагаем сделать два наиболее простых:
#
# - $\text{Uniform}$. Значения признака $[\min f_i, \max f_i]$ отображаются в `nbins` отрезков одинаковой длины, которые полностью покрывают интервал
# - $\text{Quantile}$. Тот же самый отрезок сортируется и бьется на `nbins` квантилей от 0 до 1
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `colsample_bytree`, `tree_method` | `colsample_bytree`, `max_bin`| `rsm`, `quantize(...)`|
#
# Нужно добавить параметры:
# - `rsm: float | int = 1.0` — доля или число признаков, участвующих в обучении модели. Каждый признак либо входит, либо не входит в пул, на котором обучается базовый алгоритм, по аналогии с бутстрапом Бернулли
# - `quantization_type: str | None = None` — тип квантизации, если она есть
# - `nbins: int = 255` — число бинов для квантизации. Игнорируем, если тип квантизации не указан
#
# <font color='plum'>**Вопрос**: как квантизация поможет в обработке выбросов и нанов?</font>
#
# <font color='plum'>**Ответ**: КВАНТизация не может не помогать. Эх заботаю слупизацию - квантизацией стану </font>
#
# <font color='plum'>**Вопрос**: можно ли просто заполнить наны каким-то числом? Имеет ли значение, что это за число (-1, -100, -1e32)?</font>
#
# <font color='plum'>**Ответ**: честно скажу, эмпирически выявил, что наны следует заполнять числом 94. Статистики прокрашиваются, лоссы улучшаются, ситуация в мире становится более спокойной.</font>

# %%
#

# %% [markdown]
# ### Бонус. Квантизация (1 балл)
#
# В текущих имплементациях бустинга используются более сложные методы квантизации. К сожалению, способы выше страдают либо от неравноправности бинов — в каких-то объектов больше, в каких-то меньше, либо от того, что целевая переменная от бинов зависит опосредованно. Предлагается это исправить следующими способами:
#
# 1. $\text{MinEntropy}$. Это [один из методов](https://catboost.ai/docs/en/concepts/quantization), который используется для бинаризации в <font color='palegoldenrod'>**CatBoost**</font>, остальные на него очень похожи. Будем жадно набирать бины так, чтобы энтропия объектов внутри ($\sum_{i \in \text{bin}} x_i\log(x_i)$) была как можно меньше. Сделать такое разбиение руками непросто, но вам эта задача должна что-то напоминать
#
# 2. $\text{PiecewiseEncoding}$. Это относительно свежий метод для [табличных трансформеров](https://arxiv.org/pdf/2203.05556). Суть заключается в том, что бины для квантизации будем брать не с потолка, а именно те, что нужны для разбиения таргета. (В статье делается кодирование в вектор длины $T$, где $T$ число бинов, в нашем случае это излишне, бинов можно оставить столько же, но взять лмшь закодированную по формуле часть)
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | — | — | `feature_border_type="MinEntropy"` |
#
# Нужно добавить опцию:
#
# - `'MinEntropy'` для `quantization_type` — какую квантизацию используем
#
# Реализуйте оба способа подсчета (или один, но тогда балл неполный) и сравните, удалось ли улучшить качество?

# %%
#

# %% [markdown]
# ### 2.4. Важность признаков (0.5 балла)
#
# Поскольку наша базовая модель — это дерево из `sklearn`, мы можем вычислить важность признака отдельно для каждого дерева и усреднить (воспользуйтесь `feature_importances_` у `DecisionTreeRegressor`), после этого нормировать значения, чтобы они суммировались в единицу (обратите внимание, что они должны быть неотрицательными — иначе вы что-то сделали не так). Разумеется, способ не единственный, если хочется, посмотрите в документации
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `model.get_score()` | `lightgbm.importance()` | `model.get_feature_importance()` |
#
# Допишите к бустингу:
# - `feature_importances_` — атрибут, который возвращает важность признаков, согласно методу выше

# %%
boosting = Boosting(n_estimators=100, bootstrap_type = "Bayesian")

boosting.fit(X_train, y_train)
boosting.plot_history(X_valid, y_valid)

boosting.feature_importances_
# Out:
# array([ 2.09055504e-03,  4.91140032e-03,  2.39074114e-03,  1.67026324e-03,
#         1.84231374e-03,  1.38521884e-03,  8.10447210e-04,  6.05419555e-04,
#         5.97929100e-04,  2.03021173e-03,  4.07787198e-03,  5.21299220e-04,
#         2.03019195e-03,  6.25082275e-05,  2.98228871e-04,  1.67906079e-03,
#         4.61065993e-05,  2.79701467e-04,  1.60624686e-04,  1.23712949e-03,
#         4.15478339e-03,  3.47797955e-03,  9.94509225e-04,  6.25718309e-04,
#         4.25562550e-03,  1.65823130e-03,  6.33584826e-05,  2.70197547e-03,
#         1.67205918e-04,  6.30559874e-04,  1.44441208e-03,  7.32764773e-04,
#         4.46198712e-04,  1.04611279e-04,  4.14954595e-04,  1.76751289e-03,
#         1.27375935e-02,  7.34593065e-04,  1.07747412e-04,  2.53646362e-05,
#         3.61719700e-04,  0.00000000e+00,  3.11357529e-04,  3.20578218e-04,
#         6.98489837e-06,  2.10473929e-04,  3.37432828e-04,  1.29059421e-04,
#         2.13666405e-04,  0.00000000e+00,  8.24112976e-04,  3.09808179e-04,
#         1.78634502e-04,  1.85642039e-04,  1.12521323e-04,  2.21322275e-05,
#         1.06911847e-04,  8.67503579e-04,  3.23735922e-06,  8.45645136e-04,
#         3.45451863e-04,  5.04292389e-05,  9.39850544e-04,  4.70661743e-04,
#         6.01700478e-04,  3.89307287e-04,  1.16023742e-06,  1.22163681e-04,
#         2.60946034e-04,  1.19835466e-03,  8.55383904e-04,  2.68752266e-03,
#         4.42548173e-04,  1.10983183e-04,  3.96215133e-04,  8.54751450e-04,
#         3.31757187e-04, -1.26833213e-18,  9.72339410e-06,  6.05886767e-04,
#         1.16662051e-03,  5.13980955e-04,  3.49412817e-04,  1.48272561e-03,
#         4.58341398e-04,  1.67643439e-04,  5.22521871e-06,  0.00000000e+00,
#         1.82144375e-04,  4.54653186e-04,  2.04688133e-04,  3.01419750e-04,
#         8.86830120e-04,  3.48856270e-04,  5.17458098e-04,  7.51036553e-04,
#         0.00000000e+00,  8.76376360e-07,  0.00000000e+00,  2.73989248e-04,
#         5.71849000e-05,  2.84985226e-04,  3.47973795e-04,  2.47921695e-04,
#         8.28164682e-04,  1.62871680e-04,  4.23969480e-04,  2.85805551e-04,
#         3.51571384e-04,  6.01525938e-04,  1.09364986e-03,  2.52383909e-04,
#         0.00000000e+00,  8.16513813e-05,  7.41341185e-06,  4.40921729e-04,
#         1.06040453e-03,  1.32747794e-08,  6.23533850e-05,  2.08735341e-04,
#         7.78877920e-04,  2.17859393e-03,  1.73351955e-04,  4.22072221e-04,
#         3.58601665e-04,  3.43590183e-04,  5.14016565e-04,  6.64926160e-04,
#         8.44249998e-04,  2.29169604e-04,  1.13514701e-03,  4.80913031e-05,
#         4.07541940e-04,  1.21496511e-03,  3.82985529e-04,  2.14843999e-03,
#         4.78952949e-04,  8.22440728e-04,  9.31344589e-04,  8.38789022e-04,
#         7.70712474e-05,  8.15253618e-04,  1.18854782e-02,  1.18496262e-03,
#         1.32771797e-03,  1.01518763e-03,  2.14370639e-03,  8.62371306e-04,
#         1.70832498e-03,  1.62398175e-03,  1.18806460e-03,  2.27656559e-03,
#         1.65767431e-03,  1.76376028e-03,  3.69155538e-03,  4.91497515e-03,
#         3.33163251e-03,  3.13706008e-03,  1.32563282e-02,  3.01818946e-03,
#         3.05163620e-03,  1.01261554e-02,  7.15976620e-03,  4.85618659e-03,
#         1.75135276e-01,  3.07947776e-02,  5.59276999e-01,  7.99196326e-03,
#         2.89506844e-02])

# %% [markdown]
# Покажите, какие признаки оказались самыми важными

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 15))
feature_imp_boosting = boosting.feature_importances_.reshape((-1, ))
boosting_features_indices = np.argsort(feature_imp_boosting)[::-1]
sns.barplot(x=feature_imp_boosting[boosting_features_indices][:60], y=boosting_features_indices[:60], ax=ax, orient="h")
ax.set_xlabel('Feature number')
ax.set_ylabel('Importance score (0 to 1, all sum up to 1)')
ax.set_title('Feature importances for gradient boosting classifier')
# Out:
# Text(0.5, 1.0, 'Feature importances for gradient boosting classifier')

# %% [markdown]
# 166 самый значимый!!!!!! крутой результат

# %% [markdown]
# ### Бонус. DART (1.5 балла)
#
# Ранее мы обсуждали, что каждый базовый алгоритм пытается исправить ошибки всего предыдущего ансамбля. Из-за этого возникает неравноправие — каждая новая модель вносит все меньший и меньший вклад. Уверенные обучатели нейросетей знают, что это может привести к переобучению. Но выход есть, и выход этот [DART](https://arxiv.org/pdf/1505.01866)!
#
# В DL есть такой вид регуляризации, как dropout, когда некоторые узлы нейросети со случайным шансом отключаются. Можно попробовать обобщить этот подход на случай бустингов и случайно выкидывать деревья из композиции во время обучения
#
# 1. Выбираем, какие деревья убрать. При подсчете антиградиента берем не весь ансамбль, а только ту часть, что осталась
# 2. Домножаем выходы дерева на $1/k$, где $k$ — число удаленных деревьев, чтобы учесть тот факт, что ансамбль был не весь. Тогда вклад отдельного дерева будет не настолько большим
# 3. Домножаем выходы выкинутых деревьев на $k/(k+1)$, чтобы масштабы выходов примерно совпадали
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `XGBClassifier(booster="dart")` | `LGBMClassifier(boosting_type="dart")` | — |
#
# Параметры, которые нужно добавить:
#
# - `dart: bool | None = False` — DART бустинг или нет
# - `dropout_rate: int | float = 0.05` — доля деревьев, которую выкидываем во время обучения DART

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ------
#
# ## Задание 3. Оптимизация (3.5 балла + 0.5 бонус)
#
# Теперь давайте подумаем, как же правильно применять бустинги. Нас интересует: какие бустинги вообще бывают, как их правильно тюнить, и как интерпретировать
#
# Оптимизация моделей с большим числом гиперпараметров это сложное дело. Нетрудно догадаться, что в случае, когда параметров $m$, сложность перебора в самом худшем случае будет порядка $n^m$. У бустингов, хотя на самом деле не только, эта проблема стоит особенно остро. Подумаем, как это делать умнее
#
# ### 3.1. Знакомство с optuna (1 балл)
#
# Для эффективного подбора гиперпараметров существует несколько решений, основанных на байесовской оптимизации. В этом задании предлагается познакомиться с библиотекой [optuna](https://optuna.org/), которая делает перебор гиперпараметров легким и приятным, а также сохраняет всю историю экспериментов в одно место за вас
#
# Подберите на валидации оптимальные значения следующих гиперпараметров для вашей реализации бустинга:
# - `max_depth`
# - `n_estimators`
# - `learning_rate`
# - любые другие параметры, которые вам понравились
#
# Заметим, что оптуна это крайне гибкая библиотека, в которой можно реализовать абсолютно любую логику, которую пожелаете. За вас там есть лишь выбор модели. Чтобы не плодить несколько `objective`, можно слегка менять тело функции, например, добавить опциональные параметры, но шаблоном пользоваться не обязательно, как обычно
#
# Подберите диапазон параметров самостоятельно, не забывайте фиксировать сид (нет, его не нужно перебирать). Сохраните и покажите оптимальный набор параметров. Сравните графики функций потерь для оптимального и дефолтного бустингов. Покажите, какие параметры дали наибольший прирост (для этого придется почитать документацию оптуны)

# %%
import optuna

def objective(study, model="custom_boosting"):
    early_stopping_rounds = study.suggest_int("early_stopping_rounds", 2, 32, log=True)
    min_samples_split = study.suggest_int("min_samples_split", 2, 15)
    min_samples_leaf = study.suggest_int("min_samples_leaf", 1, 12)
    max_depth = study.suggest_int("max_depth", 2, 32, log=True)
    n_estimators = study.suggest_int("n_estimators", 5, 50)
    learning_rate = study.suggest_float("learning_rate", 1e-10, 1, log=True)
    subsample = study.suggest_float("subsample", 0.1, 1)
    tree_params = {"max_depth": max_depth, "min_samples_split": min_samples_split, "min_samples_leaf": min_samples_leaf}
    boosting = Boosting(base_model_params=tree_params, n_estimators=n_estimators, learning_rate=learning_rate,
                           subsample=subsample, early_stopping_rounds=early_stopping_rounds)
    boosting.fit(X_train, y_train, X_valid, y_valid)
    return boosting.score(X_valid, y_valid)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
print(study.best_trial)
# Out:
# [I 2024-12-22 22:48:19,405] A new study created in memory with name: no-name-cc00b163-1e8a-4d2e-b7b3-bdf0880d1358
# [I 2024-12-22 22:48:27,111] Trial 0 finished with value: 0.9276376021385134 and parameters: {'early_stopping_rounds': 16, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_depth': 22, 'n_estimators': 28, 'learning_rate': 2.0839861695055876e-06, 'subsample': 0.9344990932576721}. Best is trial 0 with value: 0.9276376021385134.
# [I 2024-12-22 22:48:30,025] Trial 1 finished with value: 0.934310478731004 and parameters: {'early_stopping_rounds': 16, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_depth': 15, 'n_estimators': 14, 'learning_rate': 0.038450959748868134, 'subsample': 0.7062629081360247}. Best is trial 1 with value: 0.934310478731004.
# [I 2024-12-22 22:48:30,182] Trial 2 finished with value: 0.9009943863228379 and parameters: {'early_stopping_rounds': 4, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_depth': 3, 'n_estimators': 41, 'learning_rate': 4.1811991084330075e-08, 'subsample': 0.1412228633011021}. Best is trial 1 with value: 0.934310478731004.
# [I 2024-12-22 22:48:30,756] Trial 3 finished with value: 0.9289909349450406 and parameters: {'early_stopping_rounds': 2, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_depth': 23, 'n_estimators': 26, 'learning_rate': 1.924828689069954e-07, 'subsample': 0.48689482686163366}. Best is trial 1 with value: 0.934310478731004.
# [I 2024-12-22 22:48:31,106] Trial 4 finished with value: 0.8801979194353917 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_depth': 2, 'n_estimators': 39, 'learning_rate': 0.015294572184162289, 'subsample': 0.28904591651890804}. Best is trial 1 with value: 0.934310478731004.
# [I 2024-12-22 22:48:31,856] Trial 5 finished with value: 0.9295169428008361 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_depth': 28, 'n_estimators': 6, 'learning_rate': 0.4571374198391628, 'subsample': 0.33300938128857893}. Best is trial 1 with value: 0.934310478731004.
# [I 2024-12-22 22:48:33,689] Trial 6 finished with value: 0.9366922806152136 and parameters: {'early_stopping_rounds': 13, 'min_samples_split': 9, 'min_samples_leaf': 11, 'max_depth': 10, 'n_estimators': 21, 'learning_rate': 0.000974172123108045, 'subsample': 0.46691596500335797}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:34,000] Trial 7 finished with value: 0.9114343252452641 and parameters: {'early_stopping_rounds': 5, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_depth': 3, 'n_estimators': 10, 'learning_rate': 0.24449683172307546, 'subsample': 0.3151166880947173}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:34,390] Trial 8 finished with value: 0.8491419047869907 and parameters: {'early_stopping_rounds': 2, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 4, 'n_estimators': 50, 'learning_rate': 1.3033902459229525e-08, 'subsample': 0.895643555780646}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:34,605] Trial 9 finished with value: 0.915109196517014 and parameters: {'early_stopping_rounds': 2, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_depth': 10, 'n_estimators': 11, 'learning_rate': 3.613386501765012e-08, 'subsample': 0.18359128134736385}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:36,707] Trial 10 finished with value: 0.9301503073434368 and parameters: {'early_stopping_rounds': 29, 'min_samples_split': 12, 'min_samples_leaf': 12, 'max_depth': 6, 'n_estimators': 21, 'learning_rate': 0.00014077356910812826, 'subsample': 0.5732871115736452}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:41,083] Trial 11 finished with value: 0.9344018715982099 and parameters: {'early_stopping_rounds': 17, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_depth': 12, 'n_estimators': 20, 'learning_rate': 0.00044026688637927155, 'subsample': 0.7337486153013544}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:44,202] Trial 12 finished with value: 0.9330533279375623 and parameters: {'early_stopping_rounds': 15, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_depth': 10, 'n_estimators': 20, 'learning_rate': 0.00022631573122715832, 'subsample': 0.7537236235983945}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:49,121] Trial 13 finished with value: 0.5 and parameters: {'early_stopping_rounds': 31, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 8, 'n_estimators': 32, 'learning_rate': 1.1700572395322966e-10, 'subsample': 0.5702787767296895}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:52,156] Trial 14 finished with value: 0.9351493774509452 and parameters: {'early_stopping_rounds': 12, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_depth': 15, 'n_estimators': 18, 'learning_rate': 0.0007313115450316433, 'subsample': 0.7348490305411554}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:54,017] Trial 15 finished with value: 0.9345798681867417 and parameters: {'early_stopping_rounds': 11, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_depth': 17, 'n_estimators': 16, 'learning_rate': 0.0026315102430763595, 'subsample': 0.4663699120767457}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:54,589] Trial 16 finished with value: 0.9276695297777119 and parameters: {'early_stopping_rounds': 4, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 6, 'n_estimators': 26, 'learning_rate': 8.231579828946775e-06, 'subsample': 0.655973377157682}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:48:59,305] Trial 17 finished with value: 0.9310845898854836 and parameters: {'early_stopping_rounds': 11, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_depth': 32, 'n_estimators': 32, 'learning_rate': 3.6193256498174416e-05, 'subsample': 0.8620024558244047}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:01,517] Trial 18 finished with value: 0.9291477794726033 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_depth': 16, 'n_estimators': 17, 'learning_rate': 0.003197314661409025, 'subsample': 0.8040687015867296}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:01,908] Trial 19 finished with value: 0.9319645954408928 and parameters: {'early_stopping_rounds': 24, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_depth': 8, 'n_estimators': 5, 'learning_rate': 1.5359621443847834e-06, 'subsample': 0.4040455033477428}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:03,429] Trial 20 finished with value: 0.9167598554635774 and parameters: {'early_stopping_rounds': 11, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_depth': 5, 'n_estimators': 24, 'learning_rate': 0.0022944017136737253, 'subsample': 0.9990431468346876}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:05,329] Trial 21 finished with value: 0.9362600601995636 and parameters: {'early_stopping_rounds': 11, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_depth': 17, 'n_estimators': 16, 'learning_rate': 0.0032197658075744135, 'subsample': 0.46817317559293503}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:07,146] Trial 22 finished with value: 0.9332975743774311 and parameters: {'early_stopping_rounds': 22, 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_depth': 13, 'n_estimators': 11, 'learning_rate': 0.038316173420428555, 'subsample': 0.6211505672282143}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:09,353] Trial 23 finished with value: 0.9338199903738169 and parameters: {'early_stopping_rounds': 12, 'min_samples_split': 2, 'min_samples_leaf': 11, 'max_depth': 21, 'n_estimators': 15, 'learning_rate': 4.012197460951536e-05, 'subsample': 0.4623838981431634}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:10,406] Trial 24 finished with value: 0.9361527035127587 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 6, 'min_samples_leaf': 12, 'max_depth': 11, 'n_estimators': 22, 'learning_rate': 0.000865062452228437, 'subsample': 0.3916385925913387}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:11,253] Trial 25 finished with value: 0.9362237425099753 and parameters: {'early_stopping_rounds': 7, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_depth': 10, 'n_estimators': 30, 'learning_rate': 0.014821140410504781, 'subsample': 0.37505277692037947}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:11,566] Trial 26 finished with value: 0.927538626456998 and parameters: {'early_stopping_rounds': 3, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_depth': 8, 'n_estimators': 31, 'learning_rate': 0.01696324652149077, 'subsample': 0.2305487960812529}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:12,929] Trial 27 finished with value: 0.9335430181037696 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_depth': 18, 'n_estimators': 36, 'learning_rate': 0.08381344723860933, 'subsample': 0.5094445650913809}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:14,130] Trial 28 finished with value: 0.9331870249267059 and parameters: {'early_stopping_rounds': 9, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_depth': 9, 'n_estimators': 29, 'learning_rate': 0.007273542603239825, 'subsample': 0.40430643080001843}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:16,467] Trial 29 finished with value: 0.9330445478367826 and parameters: {'early_stopping_rounds': 19, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_depth': 22, 'n_estimators': 48, 'learning_rate': 0.23755012082756832, 'subsample': 0.25130435520341365}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:18,222] Trial 30 finished with value: 0.9357927193807954 and parameters: {'early_stopping_rounds': 14, 'min_samples_split': 8, 'min_samples_leaf': 11, 'max_depth': 13, 'n_estimators': 28, 'learning_rate': 3.1618332610004115e-05, 'subsample': 0.3478808312814104}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:19,363] Trial 31 finished with value: 0.9340366992248768 and parameters: {'early_stopping_rounds': 9, 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_depth': 11, 'n_estimators': 23, 'learning_rate': 0.0008793266857606393, 'subsample': 0.40002472413706885}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:20,141] Trial 32 finished with value: 0.9326366722460216 and parameters: {'early_stopping_rounds': 7, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_depth': 7, 'n_estimators': 24, 'learning_rate': 0.00012076766281537968, 'subsample': 0.5319926123176626}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:21,009] Trial 33 finished with value: 0.9358685475238918 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_depth': 14, 'n_estimators': 36, 'learning_rate': 0.06062219952237349, 'subsample': 0.3881820287280561}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:21,637] Trial 34 finished with value: 0.9315247922109331 and parameters: {'early_stopping_rounds': 4, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_depth': 11, 'n_estimators': 13, 'learning_rate': 0.006132445157648779, 'subsample': 0.44463125220532}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:22,203] Trial 35 finished with value: 0.9301399308606975 and parameters: {'early_stopping_rounds': 9, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 6, 'n_estimators': 21, 'learning_rate': 1.975139240361754e-06, 'subsample': 0.2714935595456569}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:22,529] Trial 36 finished with value: 0.9238174601084104 and parameters: {'early_stopping_rounds': 5, 'min_samples_split': 4, 'min_samples_leaf': 11, 'max_depth': 20, 'n_estimators': 8, 'learning_rate': 0.0012149926037795284, 'subsample': 0.1313254658805813}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:23,646] Trial 37 finished with value: 0.93094490646399 and parameters: {'early_stopping_rounds': 7, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_depth': 26, 'n_estimators': 26, 'learning_rate': 0.023052431916116167, 'subsample': 0.3574337230540402}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:24,878] Trial 38 finished with value: 0.9193400078063078 and parameters: {'early_stopping_rounds': 14, 'min_samples_split': 8, 'min_samples_leaf': 12, 'max_depth': 4, 'n_estimators': 19, 'learning_rate': 1.0248728819973594e-05, 'subsample': 0.6394645349835502}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:25,274] Trial 39 finished with value: 0.8818988644136929 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_depth': 2, 'n_estimators': 13, 'learning_rate': 0.6057853138748122, 'subsample': 0.30407195715243407}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:25,809] Trial 40 finished with value: 0.9297097059224974 and parameters: {'early_stopping_rounds': 3, 'min_samples_split': 11, 'min_samples_leaf': 11, 'max_depth': 10, 'n_estimators': 36, 'learning_rate': 0.0003118701704374439, 'subsample': 0.5055591214418382}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:26,628] Trial 41 finished with value: 0.9340007806307784 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_depth': 13, 'n_estimators': 42, 'learning_rate': 0.10042069416581978, 'subsample': 0.3786899473736255}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:27,476] Trial 42 finished with value: 0.9331570927649575 and parameters: {'early_stopping_rounds': 5, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_depth': 14, 'n_estimators': 35, 'learning_rate': 0.06815192736219682, 'subsample': 0.4271613505831862}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:28,203] Trial 43 finished with value: 0.9322718989681785 and parameters: {'early_stopping_rounds': 10, 'min_samples_split': 4, 'min_samples_leaf': 12, 'max_depth': 9, 'n_estimators': 40, 'learning_rate': 0.009060674631442577, 'subsample': 0.19162521397722193}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:30,078] Trial 44 finished with value: 0.9350308460904208 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_depth': 18, 'n_estimators': 44, 'learning_rate': 0.9143700322694867, 'subsample': 0.5562189871198039}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:32,387] Trial 45 finished with value: 0.9355037742460488 and parameters: {'early_stopping_rounds': 13, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_depth': 15, 'n_estimators': 30, 'learning_rate': 0.19218068643423544, 'subsample': 0.4851682654124089}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:33,147] Trial 46 finished with value: 0.9311280912938915 and parameters: {'early_stopping_rounds': 7, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_depth': 11, 'n_estimators': 33, 'learning_rate': 0.028101321040436063, 'subsample': 0.3139385244876764}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:35,935] Trial 47 finished with value: 0.9349506278969343 and parameters: {'early_stopping_rounds': 17, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_depth': 25, 'n_estimators': 22, 'learning_rate': 0.002017813230167567, 'subsample': 0.3644805237971543}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:36,546] Trial 48 finished with value: 0.5 and parameters: {'early_stopping_rounds': 4, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_depth': 7, 'n_estimators': 38, 'learning_rate': 1.1675232319186823e-09, 'subsample': 0.5907232153007567}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:37,206] Trial 49 finished with value: 0.9333346902579992 and parameters: {'early_stopping_rounds': 5, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_depth': 9, 'n_estimators': 26, 'learning_rate': 9.587045005399585e-05, 'subsample': 0.44661784318306474}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:38,333] Trial 50 finished with value: 0.9363015661305217 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 12, 'n_estimators': 18, 'learning_rate': 0.005482508637140499, 'subsample': 0.5321619047425511}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:39,400] Trial 51 finished with value: 0.9342210813412483 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 12, 'n_estimators': 18, 'learning_rate': 0.00495495514387589, 'subsample': 0.5290054344667333}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:41,278] Trial 52 finished with value: 0.9320456118253589 and parameters: {'early_stopping_rounds': 10, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_depth': 19, 'n_estimators': 16, 'learning_rate': 0.0004506500721347503, 'subsample': 0.4139052770408555}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:42,932] Trial 53 finished with value: 0.9349242875945956 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_depth': 15, 'n_estimators': 20, 'learning_rate': 0.01261342402749175, 'subsample': 0.6029134316734571}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:43,771] Trial 54 finished with value: 0.9261405949555926 and parameters: {'early_stopping_rounds': 3, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 12, 'n_estimators': 14, 'learning_rate': 0.001454072398059508, 'subsample': 0.6963628641985362}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:45,866] Trial 55 finished with value: 0.9351078715199871 and parameters: {'early_stopping_rounds': 10, 'min_samples_split': 3, 'min_samples_leaf': 11, 'max_depth': 17, 'n_estimators': 34, 'learning_rate': 0.07402953932948492, 'subsample': 0.4851476054987251}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:46,516] Trial 56 finished with value: 0.9338211876602867 and parameters: {'early_stopping_rounds': 6, 'min_samples_split': 4, 'min_samples_leaf': 12, 'max_depth': 10, 'n_estimators': 23, 'learning_rate': 0.0006134256888209051, 'subsample': 0.3305878669379089}. Best is trial 6 with value: 0.9366922806152136.
# [I 2024-12-22 22:49:48,185] Trial 57 finished with value: 0.938237977447912 and parameters: {'early_stopping_rounds': 12, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 14, 'n_estimators': 18, 'learning_rate': 0.002835424777205017, 'subsample': 0.3783894296936309}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:49,588] Trial 58 finished with value: 0.9335845240347277 and parameters: {'early_stopping_rounds': 12, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_depth': 8, 'n_estimators': 17, 'learning_rate': 0.0001768173717099122, 'subsample': 0.4375736723068775}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:50,339] Trial 59 finished with value: 0.9309816232490684 and parameters: {'early_stopping_rounds': 16, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_depth': 16, 'n_estimators': 10, 'learning_rate': 0.0032307885963687743, 'subsample': 0.2141247902080501}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:51,905] Trial 60 finished with value: 0.9339201633418022 and parameters: {'early_stopping_rounds': 19, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_depth': 9, 'n_estimators': 19, 'learning_rate': 0.012912607014182372, 'subsample': 0.2906301702443652}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:53,097] Trial 61 finished with value: 0.933165872865737 and parameters: {'early_stopping_rounds': 8, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_depth': 14, 'n_estimators': 15, 'learning_rate': 6.15624053510945e-07, 'subsample': 0.38805034194471566}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:54,811] Trial 62 finished with value: 0.9370171443440587 and parameters: {'early_stopping_rounds': 11, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 11, 'n_estimators': 24, 'learning_rate': 0.00425522786926947, 'subsample': 0.46716040311892626}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:57,102] Trial 63 finished with value: 0.9347043859796157 and parameters: {'early_stopping_rounds': 13, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_depth': 12, 'n_estimators': 25, 'learning_rate': 0.004115021705860289, 'subsample': 0.47174321443003814}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:49:58,871] Trial 64 finished with value: 0.9351366063952659 and parameters: {'early_stopping_rounds': 11, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_depth': 10, 'n_estimators': 28, 'learning_rate': 0.0014600387797531389, 'subsample': 0.5332134773217703}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:00,945] Trial 65 finished with value: 0.9375024444598761 and parameters: {'early_stopping_rounds': 10, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_depth': 13, 'n_estimators': 22, 'learning_rate': 6.7870341140767e-05, 'subsample': 0.5699524797402701}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:02,328] Trial 66 finished with value: 0.9364196983955563 and parameters: {'early_stopping_rounds': 9, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_depth': 8, 'n_estimators': 22, 'learning_rate': 1.4695963233805525e-05, 'subsample': 0.5661933829054937}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:04,180] Trial 67 finished with value: 0.9264455039099384 and parameters: {'early_stopping_rounds': 15, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_depth': 5, 'n_estimators': 21, 'learning_rate': 1.3573658122369493e-05, 'subsample': 0.6682280730080854}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:05,357] Trial 68 finished with value: 0.929734449842876 and parameters: {'early_stopping_rounds': 9, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_depth': 6, 'n_estimators': 18, 'learning_rate': 4.653042382361115e-06, 'subsample': 0.5629669884407084}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:07,089] Trial 69 finished with value: 0.9345156138128544 and parameters: {'early_stopping_rounds': 12, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_depth': 8, 'n_estimators': 23, 'learning_rate': 7.848816191498564e-05, 'subsample': 0.6117880866902351}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:09,795] Trial 70 finished with value: 0.9302420993061326 and parameters: {'early_stopping_rounds': 10, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_depth': 23, 'n_estimators': 19, 'learning_rate': 4.211238770013345e-05, 'subsample': 0.5819060489428599}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:12,116] Trial 71 finished with value: 0.9373471963142733 and parameters: {'early_stopping_rounds': 13, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_depth': 12, 'n_estimators': 25, 'learning_rate': 0.000399645785345984, 'subsample': 0.5093263763844614}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:14,520] Trial 72 finished with value: 0.9381952742304842 and parameters: {'early_stopping_rounds': 13, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_depth': 13, 'n_estimators': 24, 'learning_rate': 0.0004209689488877827, 'subsample': 0.5093103612518891}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:16,479] Trial 73 finished with value: 0.936813206548678 and parameters: {'early_stopping_rounds': 13, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_depth': 11, 'n_estimators': 25, 'learning_rate': 0.00022109566698302373, 'subsample': 0.5063688742075224}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:19,541] Trial 74 finished with value: 0.9372466242507979 and parameters: {'early_stopping_rounds': 18, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_depth': 13, 'n_estimators': 25, 'learning_rate': 0.0002442027334420654, 'subsample': 0.5070318851407567}. Best is trial 57 with value: 0.938237977447912.
# [I 2024-12-22 22:50:22,743] Trial 75 finished with value: 0.9390174109398458 and parameters: {'early_stopping_rounds': 19, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_depth': 13, 'n_estimators': 25, 'learning_rate': 0.00030272205663563347, 'subsample': 0.506485684607053}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:26,593] Trial 76 finished with value: 0.937373935712102 and parameters: {'early_stopping_rounds': 23, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_depth': 13, 'n_estimators': 27, 'learning_rate': 0.00021932978226620417, 'subsample': 0.5095976191361122}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:30,880] Trial 77 finished with value: 0.9365398261380408 and parameters: {'early_stopping_rounds': 27, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_depth': 13, 'n_estimators': 27, 'learning_rate': 6.347809307191554e-05, 'subsample': 0.5060480004991204}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:35,909] Trial 78 finished with value: 0.9365226650319716 and parameters: {'early_stopping_rounds': 22, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_depth': 16, 'n_estimators': 29, 'learning_rate': 0.0003377019927578733, 'subsample': 0.6296464867671933}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:38,879] Trial 79 finished with value: 0.9367134326761826 and parameters: {'early_stopping_rounds': 19, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_depth': 14, 'n_estimators': 24, 'learning_rate': 2.0112565967223814e-05, 'subsample': 0.45962264204315195}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:43,525] Trial 80 finished with value: 0.9349725781488835 and parameters: {'early_stopping_rounds': 21, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_depth': 19, 'n_estimators': 27, 'learning_rate': 0.00019178632296966202, 'subsample': 0.5414520534715597}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:46,915] Trial 81 finished with value: 0.9377997705999123 and parameters: {'early_stopping_rounds': 25, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_depth': 11, 'n_estimators': 25, 'learning_rate': 0.00023362349157445665, 'subsample': 0.485696131355943}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:50,225] Trial 82 finished with value: 0.9356837663120303 and parameters: {'early_stopping_rounds': 24, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_depth': 13, 'n_estimators': 25, 'learning_rate': 0.0006040739210978958, 'subsample': 0.42425606853172715}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:55,252] Trial 83 finished with value: 0.9383477287076569 and parameters: {'early_stopping_rounds': 25, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_depth': 16, 'n_estimators': 26, 'learning_rate': 0.00011983266770355452, 'subsample': 0.49621136366788576}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:50:59,941] Trial 84 finished with value: 0.9368495242382664 and parameters: {'early_stopping_rounds': 28, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_depth': 15, 'n_estimators': 26, 'learning_rate': 0.0001194385388387377, 'subsample': 0.5035997105257989}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:06,858] Trial 85 finished with value: 0.9364659934723941 and parameters: {'early_stopping_rounds': 31, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_depth': 18, 'n_estimators': 29, 'learning_rate': 5.73569330878694e-05, 'subsample': 0.5878152015101997}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:12,050] Trial 86 finished with value: 0.9348356883958197 and parameters: {'early_stopping_rounds': 25, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_depth': 16, 'n_estimators': 27, 'learning_rate': 0.00030551449073593594, 'subsample': 0.5495424549931541}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:17,189] Trial 87 finished with value: 0.934310079635514 and parameters: {'early_stopping_rounds': 20, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_depth': 21, 'n_estimators': 22, 'learning_rate': 2.3111466375160387e-05, 'subsample': 0.4901771798446478}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:23,535] Trial 88 finished with value: 0.938192879657544 and parameters: {'early_stopping_rounds': 26, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_depth': 14, 'n_estimators': 28, 'learning_rate': 0.0008006849920109869, 'subsample': 0.6573238387334173}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:31,039] Trial 89 finished with value: 0.9331606846243674 and parameters: {'early_stopping_rounds': 26, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_depth': 14, 'n_estimators': 31, 'learning_rate': 0.0008786344422863637, 'subsample': 0.7793099766058258}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:35,722] Trial 90 finished with value: 0.9346904176374664 and parameters: {'early_stopping_rounds': 23, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_depth': 12, 'n_estimators': 30, 'learning_rate': 5.253237362722556e-06, 'subsample': 0.6794118462132364}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:41,454] Trial 91 finished with value: 0.9381545664905059 and parameters: {'early_stopping_rounds': 29, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_depth': 15, 'n_estimators': 28, 'learning_rate': 0.00040938150679253123, 'subsample': 0.6442716638965075}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:47,788] Trial 92 finished with value: 0.9358765294336914 and parameters: {'early_stopping_rounds': 29, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_depth': 17, 'n_estimators': 28, 'learning_rate': 0.0005856983174673512, 'subsample': 0.6515870655752386}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:52,043] Trial 93 finished with value: 0.9356059426914841 and parameters: {'early_stopping_rounds': 32, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_depth': 16, 'n_estimators': 23, 'learning_rate': 0.00012440334959628116, 'subsample': 0.5236750759815596}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:51:56,403] Trial 94 finished with value: 0.9373104795291949 and parameters: {'early_stopping_rounds': 17, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_depth': 14, 'n_estimators': 31, 'learning_rate': 0.0018131414289832776, 'subsample': 0.7254348147274419}. Best is trial 75 with value: 0.9390174109398458.
# [I 2024-12-22 22:52:02,361] Trial 95 finished with value: 0.9393047596926327 and parameters: {'early_stopping_rounds': 29, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_depth': 15, 'n_estimators': 27, 'learning_rate': 0.0010167105358912924, 'subsample': 0.5990285437683878}. Best is trial 95 with value: 0.9393047596926327.
# [I 2024-12-22 22:52:08,583] Trial 96 finished with value: 0.9360928391892614 and parameters: {'early_stopping_rounds': 26, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_depth': 15, 'n_estimators': 29, 'learning_rate': 0.0009819416734083077, 'subsample': 0.6173631117794927}. Best is trial 95 with value: 0.9393047596926327.
# [I 2024-12-22 22:52:14,838] Trial 97 finished with value: 0.9355137516332983 and parameters: {'early_stopping_rounds': 22, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_depth': 20, 'n_estimators': 32, 'learning_rate': 5.048212417332848e-05, 'subsample': 0.640705383054337}. Best is trial 95 with value: 0.9393047596926327.
# [I 2024-12-22 22:52:21,467] Trial 98 finished with value: 0.9378472629632201 and parameters: {'early_stopping_rounds': 30, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_depth': 17, 'n_estimators': 27, 'learning_rate': 0.002475333510788724, 'subsample': 0.6945667167588951}. Best is trial 95 with value: 0.9393047596926327.
# [I 2024-12-22 22:52:27,159] Trial 99 finished with value: 0.9304859466505112 and parameters: {'early_stopping_rounds': 29, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_depth': 18, 'n_estimators': 20, 'learning_rate': 0.0029058087702332745, 'subsample': 0.7027690687019591}. Best is trial 95 with value: 0.9393047596926327.
# FrozenTrial(number=95, state=TrialState.COMPLETE, values=[0.9393047596926327], datetime_start=datetime.datetime(2024, 12, 22, 22, 51, 56, 405178), datetime_complete=datetime.datetime(2024, 12, 22, 22, 52, 2, 360917), params={'early_stopping_rounds': 29, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_depth': 15, 'n_estimators': 27, 'learning_rate': 0.0010167105358912924, 'subsample': 0.5990285437683878}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'early_stopping_rounds': IntDistribution(high=32, log=True, low=2, step=1), 'min_samples_split': IntDistribution(high=15, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=12, log=False, low=1, step=1), 'max_depth': IntDistribution(high=32, log=True, low=2, step=1), 'n_estimators': IntDistribution(high=50, log=False, low=5, step=1), 'learning_rate': FloatDistribution(high=1.0, log=True, low=1e-10, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.1, step=None)}, trial_id=95, value=None)

# %%
params = study.best_trial.params
tree_params = {"min_samples_split": params["min_samples_split"],
               "min_samples_leaf": params["min_samples_leaf"],
              "max_depth": params["max_depth"],}
best_model = Boosting(base_model_params=tree_params,
                      n_estimators=params['n_estimators'],
                      subsample=params['subsample'],
                      learning_rate=params['learning_rate'],
                      early_stopping_rounds=params['early_stopping_rounds'])
best_model.fit(X_train, y_train, X_valid, y_valid)
print(f'Train ROC-AUC {best_model.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {best_model.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {best_model.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9799
# Valid ROC-AUC 0.9364
# Test ROC-AUC 0.9346

# %% [markdown]
# ### 3.2. Глубокая оптимизация (1 балл)
#
# Помимо эффективного перебора гиперпараметров, `optuna` предлагает более тонкий контроль над самой процедурой обучения. Улучшите процедуру оптимизации следующим образом:
#
# 1. Посмотрите, как в `optuna` устроена запись в хранилища, и добавьте это в пайплайн оптимизации. Без указания БД все запуски оптуны сотрутся, как только закончится сессия. Более того, так можно распараллелить процесс оптимизации на несколько машин
# 2. Посмотрите, как можно контролировать процесс обучения бустинга при помощи прунера. У библиотечных имплементаций есть уже готовые, их можно использовать пунктом ниже. Для кастомной модели возьмите что-то из `optuna.pruners`. Идея прунера — не обучать бустинг до конца, если по истории видно, что другие бустинги на этом этапе статистически лучше.
# 3. Добавьте сохранение истории функции потерь и времени обучения в качестве `user_attribute` сразу в `study`. Мы не хотим оптимизировать их напрямую, но они нам понадобится для сравнения моделей в дальнейшем
#
# Добавьте хранилище и юзер атрибуты и посмотрите, ускорилась ли оптимизация с добавлением прунера

# %%
# ну что сказать, очень интересное задание и вот так я его решил:
# старался
params = study.best_trial.params
tree_params = {"min_samples_split": params["min_samples_split"],
               "min_samples_leaf": params["min_samples_leaf"],
              "max_depth": params["max_depth"],}
best_model = Boosting(base_model_params=tree_params,
                      n_estimators=params['n_estimators'],
                      subsample=params['subsample'],
                      learning_rate=params['learning_rate'],
                      early_stopping_rounds=params['early_stopping_rounds'])
best_model.fit(X_train, y_train, X_valid, y_valid)
print(f'Train ROC-AUC {best_model.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {best_model.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {best_model.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9799
# Valid ROC-AUC 0.9364
# Test ROC-AUC 0.9346

# %% [markdown]
# ### 3.3. Готовые реализации (1 балл)
#
# Библиотек для бустингов существует много, но активно используются лишь три. Ваша задача — попробовать их в деле, посмотреть на их уникальные фишки и понять, что вам нравится больше всего
#
# Возьмите любую из популярных библиотек: <font color='lightblue'>`xgboost`</font>, <font color='lightgreen'>`lightgbm`</font>, <font color='palegoldenrod'>`catboost`</font>.
# Ваша задача — взять одну из них, подобрать те же оптимальные параметры, что и выше, плюс что-то, что вам понравилось в них больше всего (может быть абсолютно любая фишка из пунктов выше или что-то, что вы найдете сами, не обязательно эксклюзивное), и сравнить две оптимизированные модели по
# - динамике функции потерь (на обучающей и на валидационной выборке)
# - времени обучения

# %%
import xgboost as xgb
import optuna
from sklearn.metrics import roc_auc_score

def objective(study):
    params = {
        "max_depth": study.suggest_int("max_depth", 2, 32, log=True),
        "learning_rate": study.suggest_float("learning_rate", 1e-10, 1, log=True),
        "n_estimators": study.suggest_int("n_estimators", 5, 500),
        "min_child_weight": study.suggest_int("min_child_weight", 1, 20),
        "subsample": study.suggest_float("subsample", 0.1, 1),
        "colsample_bytree": study.suggest_float("colsample_bytree", 0.1, 1),
        "gamma": study.suggest_float("gamma", 0, 10),
        "reg_alpha": study.suggest_float("reg_alpha", 1e-8, 100, log=True),
        "reg_lambda": study.suggest_float("reg_lambda", 1e-8, 100, log=True)
    }

    model = xgb.XGBClassifier(
        **params,
        objective="binary:logistic",
        use_label_encoder=False,
        eval_metric="auc",
        random_state=42
    )

    model.fit(
        X_train,
        y_train,
        eval_set=[(X_valid, y_valid)],
        early_stopping_rounds=study.suggest_int("early_stopping_rounds", 2, 32, log=True),
        verbose=False
    )

    y_valid_pred = model.predict_proba(X_valid)[:, 1]
    return roc_auc_score(y_valid, y_valid_pred)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print("Best trial:")
print(study.best_trial)

best_params = study.best_trial.params
best_model = xgb.XGBClassifier(
    **best_params,
    objective="binary:logistic",
    use_label_encoder=False,
    eval_metric="auc",
    random_state=42
)
# Out:
# [I 2024-12-22 22:52:32,678] A new study created in memory with name: no-name-edcecc0a-f8a7-41f3-9420-827295140c6f
# [I 2024-12-22 22:52:32,847] Trial 0 finished with value: 0.5058403634003894 and parameters: {'max_depth': 11, 'learning_rate': 3.927835941175969e-09, 'n_estimators': 17, 'min_child_weight': 6, 'subsample': 0.7761353379195819, 'colsample_bytree': 0.13447307439134162, 'gamma': 4.05265968679873, 'reg_alpha': 6.492356642011809e-08, 'reg_lambda': 0.0013061479499757306, 'early_stopping_rounds': 20}. Best is trial 0 with value: 0.5058403634003894.
# [I 2024-12-22 22:52:33,593] Trial 1 finished with value: 0.898858028164967 and parameters: {'max_depth': 15, 'learning_rate': 4.958597606166267e-09, 'n_estimators': 433, 'min_child_weight': 7, 'subsample': 0.4543500996060471, 'colsample_bytree': 0.9213213813937214, 'gamma': 6.894951745786022, 'reg_alpha': 6.081801520809933e-07, 'reg_lambda': 98.53029309629791, 'early_stopping_rounds': 11}. Best is trial 1 with value: 0.898858028164967.
# [I 2024-12-22 22:52:34,826] Trial 2 finished with value: 0.9066395920286263 and parameters: {'max_depth': 3, 'learning_rate': 1.6034182164217763e-09, 'n_estimators': 250, 'min_child_weight': 1, 'subsample': 0.736715581044298, 'colsample_bytree': 0.8749218441222201, 'gamma': 0.3133059343618394, 'reg_alpha': 0.0021425198940561566, 'reg_lambda': 2.714952142033202e-07, 'early_stopping_rounds': 32}. Best is trial 2 with value: 0.9066395920286263.
# [I 2024-12-22 22:52:34,900] Trial 3 finished with value: 0.5 and parameters: {'max_depth': 8, 'learning_rate': 4.666982523666844e-10, 'n_estimators': 385, 'min_child_weight': 5, 'subsample': 0.3888629358979758, 'colsample_bytree': 0.2296589086015542, 'gamma': 9.587574068088864, 'reg_alpha': 0.0008737600930272305, 'reg_lambda': 1.7569270668917273e-05, 'early_stopping_rounds': 3}. Best is trial 2 with value: 0.9066395920286263.
# [I 2024-12-22 22:52:35,104] Trial 4 finished with value: 0.9367976418245688 and parameters: {'max_depth': 27, 'learning_rate': 1.2470611924637633e-07, 'n_estimators': 431, 'min_child_weight': 9, 'subsample': 0.6359781946829567, 'colsample_bytree': 0.49137833850316137, 'gamma': 2.003382416948971, 'reg_alpha': 0.7092178497309116, 'reg_lambda': 3.7474248137726398e-06, 'early_stopping_rounds': 3}. Best is trial 4 with value: 0.9367976418245688.
# [I 2024-12-22 22:52:35,280] Trial 5 finished with value: 0.5 and parameters: {'max_depth': 5, 'learning_rate': 3.2926504280797075e-10, 'n_estimators': 110, 'min_child_weight': 8, 'subsample': 0.5034831733249752, 'colsample_bytree': 0.6208279882121295, 'gamma': 4.512895304398359, 'reg_alpha': 8.27183115635606e-07, 'reg_lambda': 0.12244378381921694, 'early_stopping_rounds': 21}. Best is trial 4 with value: 0.9367976418245688.
# [I 2024-12-22 22:52:35,613] Trial 6 finished with value: 0.8994119727050611 and parameters: {'max_depth': 2, 'learning_rate': 0.00021619299824510084, 'n_estimators': 345, 'min_child_weight': 15, 'subsample': 0.6918224613317882, 'colsample_bytree': 0.9577760062870693, 'gamma': 9.564733391393368, 'reg_alpha': 6.257927431153355e-07, 'reg_lambda': 45.2220911447634, 'early_stopping_rounds': 18}. Best is trial 4 with value: 0.9367976418245688.
# [I 2024-12-22 22:52:35,726] Trial 7 finished with value: 0.9175548536796205 and parameters: {'max_depth': 3, 'learning_rate': 4.337044189603953e-06, 'n_estimators': 365, 'min_child_weight': 8, 'subsample': 0.34070111733748776, 'colsample_bytree': 0.5512407190480796, 'gamma': 0.34311728031490407, 'reg_alpha': 52.771587657242335, 'reg_lambda': 0.0013961532408006702, 'early_stopping_rounds': 4}. Best is trial 4 with value: 0.9367976418245688.
# [I 2024-12-22 22:52:36,068] Trial 8 finished with value: 0.9439761724028662 and parameters: {'max_depth': 10, 'learning_rate': 0.15344357834545305, 'n_estimators': 26, 'min_child_weight': 3, 'subsample': 0.9818298400182245, 'colsample_bytree': 0.6930061824149718, 'gamma': 8.195535200324104, 'reg_alpha': 9.404586840832186e-07, 'reg_lambda': 0.6249349443956635, 'early_stopping_rounds': 28}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:36,153] Trial 9 finished with value: 0.9105754717508239 and parameters: {'max_depth': 3, 'learning_rate': 2.8913983870578635e-05, 'n_estimators': 89, 'min_child_weight': 3, 'subsample': 0.7530295897832333, 'colsample_bytree': 0.1526277646825889, 'gamma': 1.6774146592987538, 'reg_alpha': 9.149361257815212e-06, 'reg_lambda': 0.0003785040640665796, 'early_stopping_rounds': 3}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:36,597] Trial 10 finished with value: 0.9364975220161026 and parameters: {'max_depth': 20, 'learning_rate': 0.020307138381746893, 'n_estimators': 207, 'min_child_weight': 20, 'subsample': 0.9860798364820352, 'colsample_bytree': 0.6904195346364796, 'gamma': 7.012762610174076, 'reg_alpha': 8.38080032761456e-05, 'reg_lambda': 0.2296521800644977, 'early_stopping_rounds': 7}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:36,778] Trial 11 finished with value: 0.9347530756293936 and parameters: {'max_depth': 32, 'learning_rate': 0.7993135330910208, 'n_estimators': 475, 'min_child_weight': 12, 'subsample': 0.1026367998437755, 'colsample_bytree': 0.37644161609322374, 'gamma': 2.6748983774354285, 'reg_alpha': 0.09294627759940198, 'reg_lambda': 5.223210016152455e-08, 'early_stopping_rounds': 2}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:37,126] Trial 12 finished with value: 0.9357895266168755 and parameters: {'max_depth': 32, 'learning_rate': 2.499926729047204e-07, 'n_estimators': 180, 'min_child_weight': 13, 'subsample': 0.9588302583312425, 'colsample_bytree': 0.38957062851840746, 'gamma': 6.8454067239547385, 'reg_alpha': 6.940266644078672, 'reg_lambda': 2.39041530953552e-06, 'early_stopping_rounds': 6}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:37,739] Trial 13 finished with value: 0.940270570778388 and parameters: {'max_depth': 18, 'learning_rate': 0.002032069743725086, 'n_estimators': 309, 'min_child_weight': 1, 'subsample': 0.6183897110956516, 'colsample_bytree': 0.765149498454702, 'gamma': 5.6816313031599766, 'reg_alpha': 0.14756816543503054, 'reg_lambda': 0.49754114328109866, 'early_stopping_rounds': 8}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:38,690] Trial 14 finished with value: 0.9407514808438157 and parameters: {'max_depth': 12, 'learning_rate': 0.004867028601654154, 'n_estimators': 295, 'min_child_weight': 1, 'subsample': 0.8703707792168773, 'colsample_bytree': 0.774198208588837, 'gamma': 5.712131520037779, 'reg_alpha': 0.0267444777888811, 'reg_lambda': 0.7518119148230553, 'early_stopping_rounds': 11}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:39,258] Trial 15 finished with value: 0.9433463997196753 and parameters: {'max_depth': 7, 'learning_rate': 0.8958880016968739, 'n_estimators': 279, 'min_child_weight': 4, 'subsample': 0.8866704048861029, 'colsample_bytree': 0.7799165873748489, 'gamma': 8.5255209736941, 'reg_alpha': 0.0024371873750694637, 'reg_lambda': 4.863833013368527, 'early_stopping_rounds': 13}. Best is trial 8 with value: 0.9439761724028662.
# [I 2024-12-22 22:52:40,451] Trial 16 finished with value: 0.9443205918107203 and parameters: {'max_depth': 6, 'learning_rate': 0.2708799708654454, 'n_estimators': 140, 'min_child_weight': 5, 'subsample': 0.8497956416725699, 'colsample_bytree': 0.7983453804696352, 'gamma': 8.526646084495964, 'reg_alpha': 1.0665202297495009e-08, 'reg_lambda': 7.794775625325631, 'early_stopping_rounds': 28}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:40,630] Trial 17 finished with value: 0.9350224650851311 and parameters: {'max_depth': 5, 'learning_rate': 0.09191883707173523, 'n_estimators': 11, 'min_child_weight': 4, 'subsample': 0.8636036435714061, 'colsample_bytree': 0.6541310218004642, 'gamma': 8.074315898493188, 'reg_alpha': 1.0634914987327416e-08, 'reg_lambda': 0.022195343152770747, 'early_stopping_rounds': 26}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:41,336] Trial 18 finished with value: 0.9263589001886124 and parameters: {'max_depth': 5, 'learning_rate': 0.0004845950658792443, 'n_estimators': 100, 'min_child_weight': 10, 'subsample': 0.9959311029462288, 'colsample_bytree': 0.8450539956916765, 'gamma': 8.17215964156929, 'reg_alpha': 1.5931617826333474e-08, 'reg_lambda': 9.392571289172679, 'early_stopping_rounds': 16}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:42,882] Trial 19 finished with value: 0.9436058117881633 and parameters: {'max_depth': 9, 'learning_rate': 0.10084790728744557, 'n_estimators': 148, 'min_child_weight': 19, 'subsample': 0.8231776339622612, 'colsample_bytree': 0.5087954404551768, 'gamma': 8.696223526331057, 'reg_alpha': 1.0492960797798688e-05, 'reg_lambda': 0.01121636514339353, 'early_stopping_rounds': 29}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:43,172] Trial 20 finished with value: 0.9307625198250685 and parameters: {'max_depth': 4, 'learning_rate': 0.032749396275152054, 'n_estimators': 34, 'min_child_weight': 3, 'subsample': 0.24764536900480294, 'colsample_bytree': 0.7149615635370465, 'gamma': 7.416384744306586, 'reg_alpha': 1.800616906895484e-07, 'reg_lambda': 3.0425943577350827, 'early_stopping_rounds': 15}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:44,145] Trial 21 finished with value: 0.9438831831537005 and parameters: {'max_depth': 9, 'learning_rate': 0.15236525202750809, 'n_estimators': 157, 'min_child_weight': 18, 'subsample': 0.8198248146429306, 'colsample_bytree': 0.5326745518315976, 'gamma': 9.045080215379933, 'reg_alpha': 9.550588307933792e-06, 'reg_lambda': 0.0057852546897659085, 'early_stopping_rounds': 32}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:45,404] Trial 22 finished with value: 0.9426751211055264 and parameters: {'max_depth': 12, 'learning_rate': 0.2755780211948147, 'n_estimators': 61, 'min_child_weight': 17, 'subsample': 0.9060892935156795, 'colsample_bytree': 0.5889954206152088, 'gamma': 9.614873241145615, 'reg_alpha': 4.134794501408568e-06, 'reg_lambda': 0.029948697934246666, 'early_stopping_rounds': 24}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:46,482] Trial 23 finished with value: 0.9381729248830449 and parameters: {'max_depth': 6, 'learning_rate': 0.007361406180721326, 'n_estimators': 149, 'min_child_weight': 12, 'subsample': 0.8016307013926997, 'colsample_bytree': 0.40725533357631016, 'gamma': 9.960400432155977, 'reg_alpha': 6.395320054485605e-05, 'reg_lambda': 0.0002480725645245743, 'early_stopping_rounds': 32}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:47,490] Trial 24 finished with value: 0.9358673502374221 and parameters: {'max_depth': 10, 'learning_rate': 0.0007913125231629832, 'n_estimators': 225, 'min_child_weight': 5, 'subsample': 0.5934233967577536, 'colsample_bytree': 0.9958391127328297, 'gamma': 5.964018943201157, 'reg_alpha': 8.308392856748864e-08, 'reg_lambda': 0.006471406677000952, 'early_stopping_rounds': 24}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:48,519] Trial 25 finished with value: 0.9347303271864646 and parameters: {'max_depth': 8, 'learning_rate': 3.065571066551999e-05, 'n_estimators': 148, 'min_child_weight': 15, 'subsample': 0.9268364791405888, 'colsample_bytree': 0.46887132628191114, 'gamma': 8.92462638212996, 'reg_alpha': 0.00015537712013130294, 'reg_lambda': 16.812196367158844, 'early_stopping_rounds': 20}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:49,287] Trial 26 finished with value: 0.9388505890250336 and parameters: {'max_depth': 15, 'learning_rate': 0.03288730843678603, 'n_estimators': 65, 'min_child_weight': 17, 'subsample': 0.6907086218294526, 'colsample_bytree': 0.2976639895942591, 'gamma': 7.679351867526803, 'reg_alpha': 2.206613094688899e-06, 'reg_lambda': 2.4101152299860584, 'early_stopping_rounds': 10}. Best is trial 16 with value: 0.9443205918107203.
# [I 2024-12-22 22:52:50,329] Trial 27 finished with value: 0.9458842479404677 and parameters: {'max_depth': 6, 'learning_rate': 0.15779041596837065, 'n_estimators': 192, 'min_child_weight': 3, 'subsample': 0.8153494838366775, 'colsample_bytree': 0.7076093194385228, 'gamma': 9.005288753425113, 'reg_alpha': 2.3557759856623174e-05, 'reg_lambda': 0.07768084450639985, 'early_stopping_rounds': 15}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:52:50,643] Trial 28 finished with value: 0.9252294599519648 and parameters: {'max_depth': 4, 'learning_rate': 0.00012740725188034154, 'n_estimators': 204, 'min_child_weight': 2, 'subsample': 0.6936543176526843, 'colsample_bytree': 0.8439112806681583, 'gamma': 6.620995606665904, 'reg_alpha': 4.3078651883364383e-08, 'reg_lambda': 0.13999421615500723, 'early_stopping_rounds': 14}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:52:51,770] Trial 29 finished with value: 0.9370135524846488 and parameters: {'max_depth': 6, 'learning_rate': 0.007624628305473315, 'n_estimators': 122, 'min_child_weight': 7, 'subsample': 0.9292611441851544, 'colsample_bytree': 0.710088859461336, 'gamma': 3.3370265596114885, 'reg_alpha': 1.943739897294863e-07, 'reg_lambda': 1.0698501912786145, 'early_stopping_rounds': 19}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:52:52,191] Trial 30 finished with value: 0.9338136048459771 and parameters: {'max_depth': 6, 'learning_rate': 0.001475206588462597, 'n_estimators': 46, 'min_child_weight': 6, 'subsample': 0.7787903705023388, 'colsample_bytree': 0.8048522790512754, 'gamma': 5.022250718563387, 'reg_alpha': 2.7184242958255845e-05, 'reg_lambda': 0.042949044102720636, 'early_stopping_rounds': 24}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:52:53,984] Trial 31 finished with value: 0.9457226142670252 and parameters: {'max_depth': 12, 'learning_rate': 0.16119066349999003, 'n_estimators': 182, 'min_child_weight': 3, 'subsample': 0.8282107753635193, 'colsample_bytree': 0.5930538761331101, 'gamma': 9.095824544581003, 'reg_alpha': 0.0003409736277481126, 'reg_lambda': 0.0015493797966138058, 'early_stopping_rounds': 27}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:52:56,458] Trial 32 finished with value: 0.9454735786812767 and parameters: {'max_depth': 15, 'learning_rate': 0.2889895319382563, 'n_estimators': 180, 'min_child_weight': 3, 'subsample': 0.8557029637289193, 'colsample_bytree': 0.6501644731614462, 'gamma': 7.600750956045609, 'reg_alpha': 0.0002994685095904892, 'reg_lambda': 7.111096494175262e-05, 'early_stopping_rounds': 22}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:52:58,113] Trial 33 finished with value: 0.9447839416745888 and parameters: {'max_depth': 15, 'learning_rate': 0.2927978904451598, 'n_estimators': 243, 'min_child_weight': 5, 'subsample': 0.8382610474294395, 'colsample_bytree': 0.6056949767689802, 'gamma': 7.549596228769131, 'reg_alpha': 0.0006442288585719736, 'reg_lambda': 0.00010690489335927796, 'early_stopping_rounds': 18}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:02,285] Trial 34 finished with value: 0.9446394691072155 and parameters: {'max_depth': 15, 'learning_rate': 0.02693971556371816, 'n_estimators': 248, 'min_child_weight': 2, 'subsample': 0.718701246845886, 'colsample_bytree': 0.6029427505477915, 'gamma': 7.558763885713713, 'reg_alpha': 0.0006194389368731601, 'reg_lambda': 5.1884601638664486e-05, 'early_stopping_rounds': 12}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:03,808] Trial 35 finished with value: 0.9450082333399582 and parameters: {'max_depth': 21, 'learning_rate': 0.3010697482381903, 'n_estimators': 181, 'min_child_weight': 6, 'subsample': 0.7748354144340476, 'colsample_bytree': 0.6546683429548666, 'gamma': 6.363586113258076, 'reg_alpha': 0.008800255028195174, 'reg_lambda': 5.519630029145314e-05, 'early_stopping_rounds': 9}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:05,197] Trial 36 finished with value: 0.9430861894602074 and parameters: {'max_depth': 23, 'learning_rate': 0.8736233907517017, 'n_estimators': 198, 'min_child_weight': 7, 'subsample': 0.7621517954203273, 'colsample_bytree': 0.6629938966962504, 'gamma': 6.379121093224849, 'reg_alpha': 0.0071094305214749265, 'reg_lambda': 7.716861117741846e-06, 'early_stopping_rounds': 9}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:07,867] Trial 37 finished with value: 0.9386103335400647 and parameters: {'max_depth': 23, 'learning_rate': 4.614030352813668e-08, 'n_estimators': 180, 'min_child_weight': 2, 'subsample': 0.5545286912865468, 'colsample_bytree': 0.9024140281092405, 'gamma': 9.253069973929904, 'reg_alpha': 0.0003313273423416507, 'reg_lambda': 0.0015291389504567116, 'early_stopping_rounds': 16}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:08,337] Trial 38 finished with value: 0.9391766500403487 and parameters: {'max_depth': 18, 'learning_rate': 0.05636196878216782, 'n_estimators': 182, 'min_child_weight': 4, 'subsample': 0.668643130187898, 'colsample_bytree': 0.4493726391031815, 'gamma': 4.877993707201293, 'reg_alpha': 0.005074630419588511, 'reg_lambda': 8.22017153550195e-07, 'early_stopping_rounds': 5}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:08,982] Trial 39 finished with value: 0.9377111714011364 and parameters: {'max_depth': 13, 'learning_rate': 0.010801231194169243, 'n_estimators': 273, 'min_child_weight': 6, 'subsample': 0.42994228302639775, 'colsample_bytree': 0.5701538780015888, 'gamma': 6.1121619108476075, 'reg_alpha': 0.017356727616748852, 'reg_lambda': 3.278360221016343e-05, 'early_stopping_rounds': 22}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:10,231] Trial 40 finished with value: 0.939275226626374 and parameters: {'max_depth': 25, 'learning_rate': 0.0033503026879219185, 'n_estimators': 324, 'min_child_weight': 3, 'subsample': 0.5278762621184069, 'colsample_bytree': 0.730437073169481, 'gamma': 7.006800405001554, 'reg_alpha': 0.9107988137034355, 'reg_lambda': 0.0021357460318169766, 'early_stopping_rounds': 9}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:11,400] Trial 41 finished with value: 0.9444211638741955 and parameters: {'max_depth': 15, 'learning_rate': 0.3742711557917375, 'n_estimators': 243, 'min_child_weight': 5, 'subsample': 0.7958342821777743, 'colsample_bytree': 0.6135421017357462, 'gamma': 7.845053820704882, 'reg_alpha': 0.001183204895898613, 'reg_lambda': 0.00020288632245529572, 'early_stopping_rounds': 18}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:16,146] Trial 42 finished with value: 0.9453698138538816 and parameters: {'max_depth': 19, 'learning_rate': 0.07058233362821319, 'n_estimators': 230, 'min_child_weight': 8, 'subsample': 0.7446966435015967, 'colsample_bytree': 0.5526610611464288, 'gamma': 7.271539272716145, 'reg_alpha': 0.00023814263033493025, 'reg_lambda': 0.00016272651077635323, 'early_stopping_rounds': 18}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:16,646] Trial 43 finished with value: 0.9383944228799848 and parameters: {'max_depth': 19, 'learning_rate': 1.7072920213877316e-06, 'n_estimators': 221, 'min_child_weight': 9, 'subsample': 0.7465695724941965, 'colsample_bytree': 0.6461505531192604, 'gamma': 7.224504360425678, 'reg_alpha': 0.0002114151969111284, 'reg_lambda': 2.473803469345897e-05, 'early_stopping_rounds': 13}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:19,637] Trial 44 finished with value: 0.9444945974443519 and parameters: {'max_depth': 22, 'learning_rate': 0.07216987078744916, 'n_estimators': 179, 'min_child_weight': 8, 'subsample': 0.6604239049131716, 'colsample_bytree': 0.5521864501345682, 'gamma': 9.954678548997506, 'reg_alpha': 3.5106480424090706e-05, 'reg_lambda': 0.00043054351572005176, 'early_stopping_rounds': 21}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:23,511] Trial 45 finished with value: 0.9428527185985681 and parameters: {'max_depth': 27, 'learning_rate': 0.01771409161511452, 'n_estimators': 225, 'min_child_weight': 9, 'subsample': 0.7194030445819796, 'colsample_bytree': 0.5095200571409461, 'gamma': 9.320989666693315, 'reg_alpha': 0.0021560596865709504, 'reg_lambda': 8.346536196323204e-05, 'early_stopping_rounds': 16}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:23,890] Trial 46 finished with value: 0.9423406790849219 and parameters: {'max_depth': 2, 'learning_rate': 0.42813750457285904, 'n_estimators': 167, 'min_child_weight': 7, 'subsample': 0.9378230940203663, 'colsample_bytree': 0.6637754665804825, 'gamma': 8.524154546659156, 'reg_alpha': 0.053751867972893164, 'reg_lambda': 6.872601324079225e-06, 'early_stopping_rounds': 6}. Best is trial 27 with value: 0.9458842479404677.
# [I 2024-12-22 22:53:26,859] Trial 47 finished with value: 0.9462973117725987 and parameters: {'max_depth': 17, 'learning_rate': 0.11657237126955071, 'n_estimators': 127, 'min_child_weight': 1, 'subsample': 0.8789080039021566, 'colsample_bytree': 0.7488479221550356, 'gamma': 6.544242421026431, 'reg_alpha': 0.00011415562995482251, 'reg_lambda': 0.0006556278486448498, 'early_stopping_rounds': 11}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:27,738] Trial 48 finished with value: 0.9319314705152243 and parameters: {'max_depth': 13, 'learning_rate': 1.0697057613373492e-08, 'n_estimators': 122, 'min_child_weight': 1, 'subsample': 0.8924146329661322, 'colsample_bytree': 0.7597223223371828, 'gamma': 5.4148115817307625, 'reg_alpha': 2.3606757119545637e-05, 'reg_lambda': 0.0008368910856893314, 'early_stopping_rounds': 11}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:28,225] Trial 49 finished with value: 0.5 and parameters: {'max_depth': 18, 'learning_rate': 1.3078927583889897e-10, 'n_estimators': 85, 'min_child_weight': 2, 'subsample': 0.9598333817056821, 'colsample_bytree': 0.7388331336055585, 'gamma': 3.7726412264512943, 'reg_alpha': 8.667920808582899e-05, 'reg_lambda': 0.002367749027274516, 'early_stopping_rounds': 14}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:30,471] Trial 50 finished with value: 0.9447316601654012 and parameters: {'max_depth': 11, 'learning_rate': 0.05664815339552415, 'n_estimators': 275, 'min_child_weight': 3, 'subsample': 0.859314540355424, 'colsample_bytree': 0.8258644168944211, 'gamma': 8.03127050834578, 'reg_alpha': 2.5850285279432043e-06, 'reg_lambda': 2.1186465075653137e-07, 'early_stopping_rounds': 17}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:30,988] Trial 51 finished with value: 0.9422860030027945 and parameters: {'max_depth': 28, 'learning_rate': 0.9616250029669539, 'n_estimators': 134, 'min_child_weight': 4, 'subsample': 0.7896545871410887, 'colsample_bytree': 0.6887013449188796, 'gamma': 6.632476049268781, 'reg_alpha': 0.0004155836829929606, 'reg_lambda': 0.0006098779312404438, 'early_stopping_rounds': 8}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:32,560] Trial 52 finished with value: 0.9459995865370724 and parameters: {'max_depth': 17, 'learning_rate': 0.19194754258795488, 'n_estimators': 199, 'min_child_weight': 6, 'subsample': 0.748859641760385, 'colsample_bytree': 0.6351321902636731, 'gamma': 6.24733764634051, 'reg_alpha': 0.004905979373086985, 'reg_lambda': 9.361856401339722e-06, 'early_stopping_rounds': 12}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:33,095] Trial 53 finished with value: 0.9420916434991735 and parameters: {'max_depth': 17, 'learning_rate': 0.105903472831371, 'n_estimators': 209, 'min_child_weight': 1, 'subsample': 0.6289270512235559, 'colsample_bytree': 0.6311753035518967, 'gamma': 7.106434677351762, 'reg_alpha': 0.00013421053868066437, 'reg_lambda': 1.6543777674793977e-06, 'early_stopping_rounds': 12}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:40,589] Trial 54 finished with value: 0.9455310484318341 and parameters: {'max_depth': 16, 'learning_rate': 0.01611376976579619, 'n_estimators': 390, 'min_child_weight': 3, 'subsample': 0.8410670509760162, 'colsample_bytree': 0.5688117592418956, 'gamma': 5.39985221040618, 'reg_alpha': 0.0025368180394874647, 'reg_lambda': 1.0061715184089374e-05, 'early_stopping_rounds': 22}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:50,482] Trial 55 finished with value: 0.9462769579026096 and parameters: {'max_depth': 16, 'learning_rate': 0.01857221075554173, 'n_estimators': 399, 'min_child_weight': 3, 'subsample': 0.8958720177791188, 'colsample_bytree': 0.6981561690105975, 'gamma': 4.465718574134824, 'reg_alpha': 0.0018871768693541585, 'reg_lambda': 8.159776055925681e-06, 'early_stopping_rounds': 21}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:51,132] Trial 56 finished with value: 0.9405267900829559 and parameters: {'max_depth': 13, 'learning_rate': 0.01481644020483793, 'n_estimators': 395, 'min_child_weight': 2, 'subsample': 0.8962039492179525, 'colsample_bytree': 0.7402194094472855, 'gamma': 4.296634513932017, 'reg_alpha': 0.2879845055679618, 'reg_lambda': 4.6391504692359077e-07, 'early_stopping_rounds': 2}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:52,389] Trial 57 finished with value: 0.9359583440091378 and parameters: {'max_depth': 7, 'learning_rate': 0.0022698097321624546, 'n_estimators': 480, 'min_child_weight': 4, 'subsample': 0.8232982218731073, 'colsample_bytree': 0.8820322365041816, 'gamma': 5.086952544967586, 'reg_alpha': 0.0014900185408440526, 'reg_lambda': 4.417444142081173e-08, 'early_stopping_rounds': 28}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:57,700] Trial 58 finished with value: 0.9420257927433265 and parameters: {'max_depth': 17, 'learning_rate': 0.00023045889155101176, 'n_estimators': 373, 'min_child_weight': 1, 'subsample': 0.966632927938023, 'colsample_bytree': 0.5873963252136244, 'gamma': 3.984683619962682, 'reg_alpha': 0.002819733484440731, 'reg_lambda': 1.3152468154100264e-05, 'early_stopping_rounds': 26}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:58,155] Trial 59 finished with value: 0.9385943697204655 and parameters: {'max_depth': 11, 'learning_rate': 0.03498345928388386, 'n_estimators': 446, 'min_child_weight': 3, 'subsample': 0.3129024357835245, 'colsample_bytree': 0.6911385328963529, 'gamma': 3.3670345455304718, 'reg_alpha': 0.021826207706949565, 'reg_lambda': 1.4896642305977573e-07, 'early_stopping_rounds': 10}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:53:59,274] Trial 60 finished with value: 0.9461001586005477 and parameters: {'max_depth': 9, 'learning_rate': 0.1572366382838572, 'n_estimators': 417, 'min_child_weight': 2, 'subsample': 0.9172980163677158, 'colsample_bytree': 0.5261160862932796, 'gamma': 4.595547967678257, 'reg_alpha': 0.003237996739536752, 'reg_lambda': 2.1110785765063006e-06, 'early_stopping_rounds': 14}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:54:00,975] Trial 61 finished with value: 0.9462813479529993 and parameters: {'max_depth': 9, 'learning_rate': 0.11643046172748737, 'n_estimators': 427, 'min_child_weight': 2, 'subsample': 0.9145012193485342, 'colsample_bytree': 0.4446821337325112, 'gamma': 4.6727203477589345, 'reg_alpha': 0.0038234356277703314, 'reg_lambda': 3.258317245340887e-06, 'early_stopping_rounds': 14}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:54:01,917] Trial 62 finished with value: 0.946156830160125 and parameters: {'max_depth': 9, 'learning_rate': 0.18308027363110113, 'n_estimators': 413, 'min_child_weight': 2, 'subsample': 0.9134884254835283, 'colsample_bytree': 0.32608904532056737, 'gamma': 4.654043466746136, 'reg_alpha': 0.011179286144837866, 'reg_lambda': 3.0839365649921093e-06, 'early_stopping_rounds': 14}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:54:02,432] Trial 63 finished with value: 0.9452349195782678 and parameters: {'max_depth': 8, 'learning_rate': 0.46010527252981187, 'n_estimators': 411, 'min_child_weight': 2, 'subsample': 0.9947701998877015, 'colsample_bytree': 0.2852134670169559, 'gamma': 4.530911675065915, 'reg_alpha': 0.07049899656829889, 'reg_lambda': 2.786465638716508e-06, 'early_stopping_rounds': 14}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:54:03,396] Trial 64 finished with value: 0.9416390692135345 and parameters: {'max_depth': 9, 'learning_rate': 0.0053074951886216285, 'n_estimators': 452, 'min_child_weight': 1, 'subsample': 0.9419981592773004, 'colsample_bytree': 0.34313948004637695, 'gamma': 4.6994265570067295, 'reg_alpha': 0.01307029670343058, 'reg_lambda': 1.2810462401656925e-06, 'early_stopping_rounds': 13}. Best is trial 47 with value: 0.9462973117725987.
# [I 2024-12-22 22:54:04,011] Trial 65 finished with value: 0.9463232529794474 and parameters: {'max_depth': 7, 'learning_rate': 0.16868485179811604, 'n_estimators': 500, 'min_child_weight': 4, 'subsample': 0.9108738999884669, 'colsample_bytree': 0.20467187271101744, 'gamma': 3.6159190272850075, 'reg_alpha': 0.03888910685850783, 'reg_lambda': 4.921021107014465e-06, 'early_stopping_rounds': 11}. Best is trial 65 with value: 0.9463232529794474.
# [I 2024-12-22 22:54:05,331] Trial 66 finished with value: 0.9450924424883443 and parameters: {'max_depth': 10, 'learning_rate': 0.13529790478198042, 'n_estimators': 492, 'min_child_weight': 4, 'subsample': 0.914287768973034, 'colsample_bytree': 0.13880353696063188, 'gamma': 2.0925594201239623, 'reg_alpha': 0.04790377804261656, 'reg_lambda': 3.4303438853371126e-06, 'early_stopping_rounds': 12}. Best is trial 65 with value: 0.9463232529794474.
# [I 2024-12-22 22:54:05,649] Trial 67 finished with value: 0.9356147227922637 and parameters: {'max_depth': 8, 'learning_rate': 0.04089455030367492, 'n_estimators': 428, 'min_child_weight': 2, 'subsample': 0.88378819078116, 'colsample_bytree': 0.17897633096016358, 'gamma': 3.487716128294882, 'reg_alpha': 0.16742094060029253, 'reg_lambda': 1.865492008911032e-08, 'early_stopping_rounds': 10}. Best is trial 65 with value: 0.9463232529794474.
# [I 2024-12-22 22:54:06,317] Trial 68 finished with value: 0.9451543022892915 and parameters: {'max_depth': 4, 'learning_rate': 0.5642000958417667, 'n_estimators': 360, 'min_child_weight': 1, 'subsample': 0.968028666878436, 'colsample_bytree': 0.21060037628154407, 'gamma': 2.854300076976469, 'reg_alpha': 1.1316636748178164, 'reg_lambda': 6.47220005426781e-07, 'early_stopping_rounds': 8}. Best is trial 65 with value: 0.9463232529794474.
# [I 2024-12-22 22:54:08,114] Trial 69 finished with value: 0.9463248493614073 and parameters: {'max_depth': 9, 'learning_rate': 0.14008958302180777, 'n_estimators': 415, 'min_child_weight': 2, 'subsample': 0.8766821484648588, 'colsample_bytree': 0.4281375364602282, 'gamma': 4.26334339469179, 'reg_alpha': 0.004278263457450457, 'reg_lambda': 4.934744657138951e-06, 'early_stopping_rounds': 11}. Best is trial 69 with value: 0.9463248493614073.
# [I 2024-12-22 22:54:08,418] Trial 70 finished with value: 0.9376692663746885 and parameters: {'max_depth': 9, 'learning_rate': 0.0010620046088683267, 'n_estimators': 461, 'min_child_weight': 4, 'subsample': 0.9201002567079466, 'colsample_bytree': 0.43330316590081447, 'gamma': 4.298213698391357, 'reg_alpha': 0.03573444638566477, 'reg_lambda': 1.0961601269464867e-07, 'early_stopping_rounds': 7}. Best is trial 69 with value: 0.9463248493614073.
# [I 2024-12-22 22:54:09,505] Trial 71 finished with value: 0.9445971649852773 and parameters: {'max_depth': 10, 'learning_rate': 0.1787547267362785, 'n_estimators': 415, 'min_child_weight': 2, 'subsample': 0.8746777638695079, 'colsample_bytree': 0.10928913839639211, 'gamma': 2.908082404242168, 'reg_alpha': 0.006479707641304986, 'reg_lambda': 5.355616288458353e-06, 'early_stopping_rounds': 11}. Best is trial 69 with value: 0.9463248493614073.
# [I 2024-12-22 22:54:10,599] Trial 72 finished with value: 0.9463719426292252 and parameters: {'max_depth': 7, 'learning_rate': 0.08898527131517102, 'n_estimators': 337, 'min_child_weight': 5, 'subsample': 0.9520243186229829, 'colsample_bytree': 0.3524777501924583, 'gamma': 3.869965175049628, 'reg_alpha': 0.003702886973125502, 'reg_lambda': 1.8247472280647187e-05, 'early_stopping_rounds': 10}. Best is trial 72 with value: 0.9463719426292252.
# [I 2024-12-22 22:54:11,999] Trial 73 finished with value: 0.9463791263480448 and parameters: {'max_depth': 7, 'learning_rate': 0.08102452104312242, 'n_estimators': 341, 'min_child_weight': 1, 'subsample': 0.9506470835220701, 'colsample_bytree': 0.35683754772493803, 'gamma': 3.829827253130795, 'reg_alpha': 0.0008782210127873772, 'reg_lambda': 1.7719305864893565e-06, 'early_stopping_rounds': 10}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:12,423] Trial 74 finished with value: 0.9405036425445371 and parameters: {'max_depth': 7, 'learning_rate': 0.029480778644587615, 'n_estimators': 335, 'min_child_weight': 1, 'subsample': 0.9504148293128583, 'colsample_bytree': 0.3509710286206661, 'gamma': 3.7447807995869167, 'reg_alpha': 0.0009683331128193793, 'reg_lambda': 3.760628059559434e-07, 'early_stopping_rounds': 10}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:13,446] Trial 75 finished with value: 0.9383604997633364 and parameters: {'max_depth': 5, 'learning_rate': 0.010198958125657192, 'n_estimators': 401, 'min_child_weight': 1, 'subsample': 0.9852303490974904, 'colsample_bytree': 0.2960958356043437, 'gamma': 4.172261844752049, 'reg_alpha': 0.0006916154092627191, 'reg_lambda': 1.8180088363439757e-05, 'early_stopping_rounds': 11}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:15,369] Trial 76 finished with value: 0.9456910857233167 and parameters: {'max_depth': 7, 'learning_rate': 0.07446337575950596, 'n_estimators': 375, 'min_child_weight': 5, 'subsample': 0.8729985398633241, 'colsample_bytree': 0.2632744366146781, 'gamma': 2.3198621730078623, 'reg_alpha': 0.009232334704777662, 'reg_lambda': 1.2832713052374192e-06, 'early_stopping_rounds': 9}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:15,798] Trial 77 finished with value: 0.9449236250960822 and parameters: {'max_depth': 5, 'learning_rate': 0.6836063089060429, 'n_estimators': 351, 'min_child_weight': 3, 'subsample': 0.9998779377658763, 'colsample_bytree': 0.328347805022308, 'gamma': 5.261852078670476, 'reg_alpha': 0.013260364955666046, 'reg_lambda': 4.5934491939130075e-06, 'early_stopping_rounds': 8}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:16,716] Trial 78 finished with value: 0.9397026578961442 and parameters: {'max_depth': 8, 'learning_rate': 1.8913363291245538e-06, 'n_estimators': 312, 'min_child_weight': 2, 'subsample': 0.8989167023810796, 'colsample_bytree': 0.37408037154329477, 'gamma': 3.850226278861431, 'reg_alpha': 0.1211354347564854, 'reg_lambda': 2.1514201604195616e-05, 'early_stopping_rounds': 15}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:17,306] Trial 79 finished with value: 0.9336228372017658 and parameters: {'max_depth': 8, 'learning_rate': 0.046842331392054314, 'n_estimators': 434, 'min_child_weight': 5, 'subsample': 0.10521208490149175, 'colsample_bytree': 0.4286956240799895, 'gamma': 5.838941354456579, 'reg_alpha': 0.36307384967432166, 'reg_lambda': 3.770600215956514e-05, 'early_stopping_rounds': 6}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:17,861] Trial 80 finished with value: 0.9361044129584709 and parameters: {'max_depth': 6, 'learning_rate': 0.00402612121108477, 'n_estimators': 468, 'min_child_weight': 4, 'subsample': 0.943069659102651, 'colsample_bytree': 0.464203380252141, 'gamma': 1.2668251872979743, 'reg_alpha': 0.02524369068174666, 'reg_lambda': 9.835166860161243e-07, 'early_stopping_rounds': 10}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:19,149] Trial 81 finished with value: 0.94583236552677 and parameters: {'max_depth': 9, 'learning_rate': 0.13159977615040797, 'n_estimators': 427, 'min_child_weight': 2, 'subsample': 0.9172171574782157, 'colsample_bytree': 0.4069433709043031, 'gamma': 4.678871958836293, 'reg_alpha': 0.004382198631683811, 'reg_lambda': 2.2168717474230138e-06, 'early_stopping_rounds': 13}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:20,483] Trial 82 finished with value: 0.9454077279254297 and parameters: {'max_depth': 11, 'learning_rate': 0.22933482607254585, 'n_estimators': 500, 'min_child_weight': 2, 'subsample': 0.8556869453316185, 'colsample_bytree': 0.47890816981085504, 'gamma': 3.1104485267821325, 'reg_alpha': 0.0017350322699823352, 'reg_lambda': 3.647851996944765e-06, 'early_stopping_rounds': 14}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:22,174] Trial 83 finished with value: 0.9421834354618692 and parameters: {'max_depth': 7, 'learning_rate': 0.019883920688622134, 'n_estimators': 407, 'min_child_weight': 1, 'subsample': 0.9697037456321989, 'colsample_bytree': 0.21497358407452863, 'gamma': 3.590085557421914, 'reg_alpha': 0.0032383629032071135, 'reg_lambda': 2.7995174897722557e-07, 'early_stopping_rounds': 16}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:23,157] Trial 84 finished with value: 0.9449779020827197 and parameters: {'max_depth': 10, 'learning_rate': 0.4468317654592106, 'n_estimators': 442, 'min_child_weight': 3, 'subsample': 0.9076640531984121, 'colsample_bytree': 0.50457726952631, 'gamma': 4.0843862810245515, 'reg_alpha': 0.00139853012367549, 'reg_lambda': 2.102129012730897e-06, 'early_stopping_rounds': 12}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:24,616] Trial 85 finished with value: 0.9443589049777584 and parameters: {'max_depth': 9, 'learning_rate': 0.08336878210232178, 'n_estimators': 293, 'min_child_weight': 14, 'subsample': 0.9341263851716901, 'colsample_bytree': 0.38261216281860816, 'gamma': 4.478064691378133, 'reg_alpha': 0.0007750247157171915, 'reg_lambda': 5.956718106094435e-06, 'early_stopping_rounds': 11}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:25,834] Trial 86 finished with value: 0.9461652111654146 and parameters: {'max_depth': 14, 'learning_rate': 0.22259925988526272, 'n_estimators': 383, 'min_child_weight': 2, 'subsample': 0.8869396214917494, 'colsample_bytree': 0.41625079244251073, 'gamma': 4.889467281778765, 'reg_alpha': 0.011327722387886126, 'reg_lambda': 1.3233305162808241e-05, 'early_stopping_rounds': 7}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:26,115] Trial 87 finished with value: 0.930428476899954 and parameters: {'max_depth': 14, 'learning_rate': 0.04742052031459453, 'n_estimators': 377, 'min_child_weight': 4, 'subsample': 0.8807560359283347, 'colsample_bytree': 0.2555129948281598, 'gamma': 4.914715592643692, 'reg_alpha': 0.00948652794195, 'reg_lambda': 1.1294784426360988e-05, 'early_stopping_rounds': 4}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:27,261] Trial 88 finished with value: 0.9455996928561109 and parameters: {'max_depth': 8, 'learning_rate': 0.2849236457859872, 'n_estimators': 339, 'min_child_weight': 1, 'subsample': 0.804221618628396, 'colsample_bytree': 0.4072080894842827, 'gamma': 5.257540738722239, 'reg_alpha': 2.9112137319818423, 'reg_lambda': 4.3499239906248186e-05, 'early_stopping_rounds': 8}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:28,575] Trial 89 finished with value: 0.9454831569730362 and parameters: {'max_depth': 12, 'learning_rate': 0.09270506513858089, 'n_estimators': 362, 'min_child_weight': 3, 'subsample': 0.8451640382160807, 'colsample_bytree': 0.3260946473938433, 'gamma': 3.13074991002506, 'reg_alpha': 4.937508346719392e-05, 'reg_lambda': 6.834235272945436e-07, 'early_stopping_rounds': 7}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:29,416] Trial 90 finished with value: 0.9392572673293248 and parameters: {'max_depth': 14, 'learning_rate': 0.009135635278789574, 'n_estimators': 384, 'min_child_weight': 10, 'subsample': 0.9467433951528608, 'colsample_bytree': 0.36052391613207724, 'gamma': 4.378019456163022, 'reg_alpha': 0.03114539823765128, 'reg_lambda': 0.0001111290779805441, 'early_stopping_rounds': 5}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:30,538] Trial 91 finished with value: 0.9409063298939284 and parameters: {'max_depth': 10, 'learning_rate': 0.1839604960915017, 'n_estimators': 420, 'min_child_weight': 2, 'subsample': 0.9050525697837681, 'colsample_bytree': 0.526229169506017, 'gamma': 4.7072761769588825, 'reg_alpha': 64.97285663800281, 'reg_lambda': 1.9470010374524757e-06, 'early_stopping_rounds': 9}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:31,257] Trial 92 finished with value: 0.9380212685968521 and parameters: {'max_depth': 20, 'learning_rate': 0.9701349147686276, 'n_estimators': 403, 'min_child_weight': 2, 'subsample': 0.9272482391380172, 'colsample_bytree': 0.44045904041160927, 'gamma': 3.9831144513537766, 'reg_alpha': 0.0043136870003465016, 'reg_lambda': 1.8725129673691362e-05, 'early_stopping_rounds': 17}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:31,810] Trial 93 finished with value: 0.9358749330517316 and parameters: {'max_depth': 9, 'learning_rate': 1.8806829751154747e-05, 'n_estimators': 350, 'min_child_weight': 3, 'subsample': 0.8669067938080154, 'colsample_bytree': 0.31602556204906385, 'gamma': 5.654475798731065, 'reg_alpha': 0.00045335753245871036, 'reg_lambda': 4.0661089788828956e-06, 'early_stopping_rounds': 13}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:32,361] Trial 94 finished with value: 0.9400438845400784 and parameters: {'max_depth': 12, 'learning_rate': 0.027755013730648696, 'n_estimators': 388, 'min_child_weight': 1, 'subsample': 0.9769456736119209, 'colsample_bytree': 0.49032066119575113, 'gamma': 3.646458141679138, 'reg_alpha': 0.00012091423108831427, 'reg_lambda': 1.4274228893813321e-05, 'early_stopping_rounds': 11}. Best is trial 73 with value: 0.9463791263480448.
# [I 2024-12-22 22:54:34,020] Trial 95 finished with value: 0.9466816407294507 and parameters: {'max_depth': 7, 'learning_rate': 0.11106593051285717, 'n_estimators': 323, 'min_child_weight': 2, 'subsample': 0.8928991479718775, 'colsample_bytree': 0.39783341116403276, 'gamma': 5.059830673985001, 'reg_alpha': 0.015976684686225182, 'reg_lambda': 6.77950133623769e-06, 'early_stopping_rounds': 20}. Best is trial 95 with value: 0.9466816407294507.
# [I 2024-12-22 22:54:34,547] Trial 96 finished with value: 0.9440711571294818 and parameters: {'max_depth': 6, 'learning_rate': 0.5607654983992035, 'n_estimators': 306, 'min_child_weight': 4, 'subsample': 0.8351015627925973, 'colsample_bytree': 0.4055537387399988, 'gamma': 5.606817943961141, 'reg_alpha': 0.016471072863122844, 'reg_lambda': 7.191788673165546e-06, 'early_stopping_rounds': 20}. Best is trial 95 with value: 0.9466816407294507.
# [I 2024-12-22 22:54:35,587] Trial 97 finished with value: 0.9460223349800013 and parameters: {'max_depth': 11, 'learning_rate': 0.3075701231164788, 'n_estimators': 319, 'min_child_weight': 1, 'subsample': 0.8928828826608428, 'colsample_bytree': 0.366698738185456, 'gamma': 5.0645324327610295, 'reg_alpha': 0.08093036493667606, 'reg_lambda': 3.3386002549921336e-05, 'early_stopping_rounds': 19}. Best is trial 95 with value: 0.9466816407294507.
# [I 2024-12-22 22:54:37,038] Trial 98 finished with value: 0.9472427689883647 and parameters: {'max_depth': 7, 'learning_rate': 0.11092630851512171, 'n_estimators': 327, 'min_child_weight': 3, 'subsample': 0.9573531657758769, 'colsample_bytree': 0.4566742529882387, 'gamma': 4.23074467963864, 'reg_alpha': 0.0074780010713484096, 'reg_lambda': 0.00031772992916329605, 'early_stopping_rounds': 15}. Best is trial 98 with value: 0.9472427689883647.
# [I 2024-12-22 22:54:38,235] Trial 99 finished with value: 0.9465180115785584 and parameters: {'max_depth': 7, 'learning_rate': 0.09834621190006176, 'n_estimators': 330, 'min_child_weight': 3, 'subsample': 0.46062556453449627, 'colsample_bytree': 0.4581004670635246, 'gamma': 4.14794655165035, 'reg_alpha': 0.0012463180130051392, 'reg_lambda': 0.004385032334670858, 'early_stopping_rounds': 24}. Best is trial 98 with value: 0.9472427689883647.
# Best trial:
# FrozenTrial(number=98, state=TrialState.COMPLETE, values=[0.9472427689883647], datetime_start=datetime.datetime(2024, 12, 22, 22, 54, 35, 588106), datetime_complete=datetime.datetime(2024, 12, 22, 22, 54, 37, 38039), params={'max_depth': 7, 'learning_rate': 0.11092630851512171, 'n_estimators': 327, 'min_child_weight': 3, 'subsample': 0.9573531657758769, 'colsample_bytree': 0.4566742529882387, 'gamma': 4.23074467963864, 'reg_alpha': 0.0074780010713484096, 'reg_lambda': 0.00031772992916329605, 'early_stopping_rounds': 15}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=32, log=True, low=2, step=1), 'learning_rate': FloatDistribution(high=1.0, log=True, low=1e-10, step=None), 'n_estimators': IntDistribution(high=500, log=False, low=5, step=1), 'min_child_weight': IntDistribution(high=20, log=False, low=1, step=1), 'subsample': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'gamma': FloatDistribution(high=10.0, log=False, low=0.0, step=None), 'reg_alpha': FloatDistribution(high=100.0, log=True, low=1e-08, step=None), 'reg_lambda': FloatDistribution(high=100.0, log=True, low=1e-08, step=None), 'early_stopping_rounds': IntDistribution(high=32, log=True, low=2, step=1)}, trial_id=98, value=None)

# %%
best_model.fit(
    X_train,
    y_train,
    eval_set=[(X_valid, y_valid)],
    verbose=False
)

print(f'Train ROC-AUC: {roc_auc_score(y_train, best_model.predict_proba(X_train)[:, 1]):.4f}')
print(f'Valid ROC-AUC: {roc_auc_score(y_valid, best_model.predict_proba(X_valid)[:, 1]):.4f}')
print(f'Test ROC-AUC: {roc_auc_score(y_test, best_model.predict_proba(X_test)[:, 1]):.4f}')
# Out:
# Train ROC-AUC: 0.9801
# Valid ROC-AUC: 0.9472
# Test ROC-AUC: 0.9404

# %% [markdown]
# <font color='plum'>**Вопрос:** Какая архитектура вам нравится больше всего и почему?</font>
#
# <font color='plum'>**Ответ**: мне больше всего нравится catboost, потому что его создала некая очень великая красная компания ЯНДЕКС ЯНДЕЕЕЕКС YOUNG##YANDEX </font>

# %% [markdown]
# ### Бонус. Random Forest (0.5 балла)
#
# Если очень захотеть, оптуна может оптимизировать все, что угодно, даже нейросети. Давайте противопоставим бустингу его злейшего врага — алгоритм Random Forest.
#
# Возьмите реализацию случайного леса из <font color='lightgreen'>`lightgbm`</font>. Посмотрите, какие там есть гиперпараметры, переберите что-либо из них вместе с `max_depth` и `n_estimators`.
#
# Сравните его качество и динамику функции потерь (на обучающей и на валидационной выборке) с таковыми у бустинга и сделайте вывод, а нужен ли Random Forest?

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ### 3.4. Бустинг и вероятности (0.5 балла)
#
# С качеством мы более-менее разобрались, но что насчет вероятностей? Постройте калибровочную кривую для вашей лучшей модели бустинга. Насколько хорошо бустинг оценивает вероятности?

# %% [markdown]
# Постройте также калибровочную кривую для логистической регрессии, сравните их между собой. Проанализируйте полученные результаты.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import calibration_curve


model = LogisticRegression()
model.fit(X_train, y_train)
boosting_pred = boosting.predict_proba(X_test)[:, 1]
logreg_pred = model.predict_proba(X_test)[:, 1]
boosting_true, boosting_pred = calibration_curve(y_test, boosting_pred, n_bins=15)
logreg_true, logreg_pred = calibration_curve(y_test, logreg_pred, n_bins=15)

plt.plot([0, 1], [0, 1], label='Perfect', linestyle='--')
plt.xlabel('Mean predicted probability')
plt.ylabel('Fraction positives')
plt.title('калибровочная кривая')
plt.plot(boosting_pred, boosting_true, label='boosting', color='m')
plt.plot(logreg_pred, logreg_true, label='logreg', color='r')
plt.legend()
plt.show()

# %% [markdown]
# ## Социализационный бонус. Новогоднее 🎆 (0.5 балла)
#
# Сфотографируйтесь с наряженной новогодней или рождественской ёлкой! Приложите фотографию, опишите свои впечатления, чего вы ждете от нового 2025 года?
#
# ![](крутые_чуваки.jpg)

# %% [markdown]
# в 2025 хочу новый альбом плейбой карти и френк оушена
